# %%
# importing all the required modules

from importlib import reload
import nltk
from bs4 import BeautifulSoup
from nltk.tokenize import sent_tokenize, word_tokenize
from sklearn.feature_extraction.text import TfidfVectorizer,CountVectorizer
import os
import errno
import string
from nltk.corpus import reuters
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from nltk import FreqDist
from nltk.text import TextCollection
import collections
import numpy as np
from nltk.tokenize import sent_tokenize, word_tokenize
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
from prettytable import PrettyTable
import time
from datetime import timedelta
from sklearn.metrics import recall_score,precision_score,average_precision_score,f1_score,accuracy_score,roc_auc_score
from sklearn.preprocessing import label_binarize
from sklearn import metrics
from sklearn.metrics.cluster import homogeneity_score,completeness_score
import statistics
import math
import sklearn.metrics 
from sklearn.model_selection import KFold
import csv
from sklearn.model_selection import train_test_split
from collections import Counter
import math
from scipy.spatial import distance
import statistics
from scipy.stats import pearsonr,entropy
from nltk.stem import WordNetLemmatizer
import matplotlib.pyplot as plt
from sklearn.naive_bayes import MultinomialNB,GaussianNB
from sklearn.datasets import fetch_20newsgroups
from sklearn.model_selection import StratifiedKFold
from scipy.io import arff



from tensorflow.keras.models import Sequential,Model
from tensorflow.keras.layers import Dense,RNN,SimpleRNNCell,LSTM,Flatten,Dropout,Input
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.layers import MaxPooling1D



from keras import layers
from sklearn import svm
from sklearn.naive_bayes import MultinomialNB
from sklearn import metrics
from sklearn.model_selection import KFold
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import KFold
import tensorflow as tf
from tensorflow.keras import backend as K
import re
import string
from sklearn.preprocessing import LabelEncoder
import gc
import string
from sklearn.preprocessing import LabelEncoder
#from keras.optimizers import SGD

def loadNewsgroupData(documents,labels):
    cat=['alt.atheism',
         'comp.windows.x',
         'misc.forsale',
         'rec.autos',
         'sci.electronics',
          'talk.politics.mideast'
        ]
    dataset = fetch_20newsgroups(subset='all',categories=cat, random_state=42)
    categories=dataset.target_names
    labels=dataset.target
    print("labels",labels)
    documents=dataset.data
    return documents,labels

def most_common(lst):
    return max(set(lst), key=lst.count)
def tokenize1(documents):
    tokens=[]
    content= documents
    tokens=(word_tokenize(content))
    tokens= [token.lower() for token in tokens ]
    tokens = [token for token in tokens if token not in stopwords]
    tokens= [token for token in tokens if token.isalpha()]
    lemmatizer = WordNetLemmatizer()
    tokens = [lemmatizer.lemmatize(token) for token in tokens]
    tokens= [token for token in tokens if len(token)>3 ]
    return tokens
def count_values_in_range(a, range_min, range_max):

    # "between" returns a boolean Series equivalent to left <= series <= right.
    # NA values will be treated as False.
    return ((range_min <= a) & (a <= range_max)).sum()
def display_scores(vectorizer, tfidf_result):
    scores = zip(vectorizer.get_feature_names(),
                 np.asarray(tfidf_result.sum(axis=0)).ravel())
def sorted_tfs(tfs,n):
    doc,terms=tfs.shape
    ind=(np.argsort(-(np.asarray(tfs.sum(axis=0)).ravel())))
    scores=np.zeros((doc,n))
    for i in range(0,len(documents)):
        for j in range(0,n):
            if(tfs[i,ind[j]]!=0):
                scores[i,j]=tfs[i,ind[j]]
    return scores

def dislay_tfidf(vectorizer,tfidf_result):
    print(vectorizer.get_feature_names())
    print(tfidf_result)
def Manhattan(doc1,doc2):
    return distance.cityblock(doc1,doc2)                       
def Euclidean(a, b):#distance
    return distance.euclidean(a,b)
def Minkowski(doc1,doc2):
    return distance.minkowski(doc1,doc2) 
def Cosine(a, b):#distance
    return distance.cosine(a,b)
def Jaccard(a, b):#distance
    return distance.jaccard(a,b)
def EnhancedJaccard(a, b):#distance
    a=[0 if x==0 else 1 for x in a]
    b=[0 if x==0 else 1 for x in b]
    return distance.jaccard(a,b)
def PCC(a, b):
    pcc, col=pearsonr(a,b)
    return abs(pcc)
def extendedJaccard(a,b):
    vector1=[0 if x==0 else 1 for x in a]
    vector2=[0 if x==0 else 1 for x in b]
    dot=np.dot(vector1,vector2)
    sum1=np.sum(vector1)
    sum2=np.sum(vector2)
    denom=math.sqrt(sum1)+math.sqrt(sum2)-dot
    if(denom!=0):
        return 1.0 - (float(dot)/(denom))
    else:
        return -1
def bhatta(a,b):

    length=len(a)
    score = 0;
    score=np.sum(np.sqrt( np.multiply(a,b) ))
    distance=-1*np.log(score)
    return distance;        

def JS(a, b):
   # normalize
    p = a/ np.sum(a)
    q = b/ np.sum(b)
    m = (p + q) / 2
    return (entropy(p, m) + entropy(q, m)) / 2

def Pairwise(a,b):
    percentage=1 #100 percent
    K1=np.count_nonzero(a)
    K2=np.count_nonzero(b)
    k=percentage*min(K1,K2)
   # setA=set((-a).argsort()[:k])
   # setB=set((-b).argsort()[:k])
    
    setA=set(np.argpartition(a, len(a)-1 - k)[-k:])
    setB=set(np.argpartition(b, len(b)-1 - k)[-k:])
    union=setA.union(setB)
    elementsA=[a[ind] for ind in union]
    elementsB=[b[ind] for ind in union]
    dist= distance.cosine(elementsA, elementsB)
    return dist

def Dice(a, b):
    a=[(a.astype(bool)).astype(int)]
    b=[(b.astype(bool)).astype(int)]
    return distance.dice(a,b)
def Extended_Dice(a, b):
    a=[0 if x==0 else 1 for x in a]
    b=[0 if x==0 else 1 for x in b]
    sim=(2*np.dot(a,b))/(sum(a)**2 + sum(b)**2)
    return sim
def simIT(a,b,termOcc,docOcc):
    p1= np.divide(a,termOcc) 
    p2= np.divide(b,termOcc)
    minVal=np.minimum(p1,p2)
    pi=np.log((np.array(docOcc)/totalDocs))
    sIT=(2*np.sum(np.multiply(minVal,pi)))/((np.sum(np.multiply(p1,pi)))+(np.sum(np.multiply(p2,pi))))
    return sIT

def ISC(doc1,doc2): 
    dot=sum(np.sqrt(np.multiply(doc1,doc2)))
    isc=dot /( math.sqrt(np.linalg.norm(doc1, ord=1))*math.sqrt(np.linalg.norm(doc2, ord=1)))
    return isc

def SP(doc1,doc2,N):
    
    a=set(np.nonzero(doc1)[0])  #indices of non zero elements in doc1
    b=set(np.nonzero(doc2)[0])  #indices of non zero elements in doc2
    nonzeroTerm=list(a.intersection(b))
    minArr=np.minimum(doc1[nonzeroTerm],doc2[nonzeroTerm])
    maxArr=np.maximum(doc1[nonzeroTerm],doc2[nonzeroTerm])
    ln=len(nonzeroTerm)
    docCount=np.zeros(ln)
    aData=allData[:,nonzeroTerm] #extracting data with only feature indices of doc1 intersection  doc2
    for ti in range(0,ln):
        docCount[ti]=count_values_in_range(aData[:,ti], minArr[ti], maxArr[ti]) #count values which lies between min and max
    normFactor= len(a.union(b))
    dCount=np.array(docCount[np.nonzero(docCount)[0]])
    SP_val=0
    if(normFactor!=0):
        SP_val=sum(np.log(totalDocs/dCount))
        SP_val = (SP_val/normFactor)
    return SP_val

def PDSM(doc1,doc2):
    a=set(np.nonzero(doc1)[0])  #indices of non zero elements in doc1
    b=set(np.nonzero(doc2)[0])  #indices of non zero elements in doc2
    intersection=sum(np.minimum(doc1,doc2))
    union=sum(np.maximum(doc1,doc2))
    PF=len(a.intersection(b))
    M=len(doc1)
    AF=len(set(range(0,M))-(a.union(b)))
    psdm=(intersection/union)*((PF+1)/(M-AF+1))
    return psdm
def EPDSM(doc1,doc2):
    a=set(np.nonzero(doc1)[0])  #indices of non zero elements in doc1
    b=set(np.nonzero(doc2)[0])  #indices of non zero elements in doc2
    intersection=np.sum(np.minimum(doc1,doc2))
    union=np.sum(np.maximum(doc1,doc2))
    PF=len(a.intersection(b))
    M=len(doc1)
    AF=M-len(a.union(b))
    psdm=(intersection/union)*((PF+1)/(M-AF+1))
    return psdm
def EEnhancedJaccard(a, b):#similarity
    a=set(np.nonzero(a)[0])  #indices of non zero elements in doc1
    b=set(np.nonzero(b)[0])  #indices of non zero elements in doc2
    union=a.union(b)
    intersection=a.intersection(b)
    sim=len(intersection)/len(union)#similarity
    return sim
def smtp(doc1,doc2,var):
    lemda=0.0001
    a=set(np.nonzero(doc1)[0])  #indices of non zero elements in doc1
    b=set(np.nonzero(doc2)[0])  #indices of non zero elements in doc2
    intersection=a.intersection(b) # indices where both docs have non zero elements
    union=a.union(b) # indices where either doc has non zero elements
    d1=np.array(list(a-intersection)) # doc1 !=0 and doc2=0
    d2=np.array(list(b-intersection)) # doc1 =0 and doc2!=0
    doc1=np.array(doc1)
    doc2=np.array(doc2)
    Nstar=0
    intersection=np.array(list(intersection))
    if (len(intersection)>0):
        term1=np.exp(-1*np.square(( doc1[intersection]-doc2[intersection] )/var[intersection]))
        Nstar=sum(0.5* (1+term1)) +lemda* -1 *(len(d1)+len(d2))
    else:
        Nstar=lemda* -1 *(len(d1)+len(d2))   
    Nunion=len(intersection)+len(d1)+len(d2)
    smtp=0
    if Nunion!=0:
        smtp=((Nstar/Nunion)+lemda)/(1+lemda)
    return smtp
def EISC(doc1,doc2): 
    dot=np.sum(np.sqrt(np.multiply(doc1,doc2)))
    isc=dot /( math.sqrt(np.linalg.norm(doc1, ord=1))*math.sqrt(np.linalg.norm(doc2, ord=1)))
    return isc

def NSMT(doc1,doc2):
    Dij=Nij=Di=Ni=Nj=Dj=0
    a=set(np.nonzero(doc1)[0])  #indices of non zero elements in doc1
    b=set(np.nonzero(doc2)[0])  #indices of non zero elements in doc2
    intersection=a.intersection(b)# indices where both docs have non zero elements
    a=np.array(list(a-intersection)) 
    b=np.array(list(b-intersection))
    intersection=np.array(list(intersection))
    if len(intersection)>0:
      #  prod=np.multiply(doc1[intersection],doc2[intersection])
        Dij=np.dot(doc1[intersection],doc2[intersection])#sum(prod)
    if len(a)>0:
        Di=sum(doc1[a])
    if len(b)>0:
        Dj=sum(doc2[b])
    Nij=len(intersection)
    Ni=len(a)
    Nj=len(b)
    Nsmt=0
    if (Ni*Di+Dj*Nj)!=0:
        Nsmt=(Nij*Dij)/(Ni*Di+Dj*Nj)
    return Nsmt
def CSMB(doc1,doc2,alpha=0.5,Beta=0.5):
    sim1=CSM_P1(doc1,doc2)
    sim2=CSM_P2(doc1,doc2)
    simValue=alpha*sim1+Beta*sim2
    return simValue
def CSMB_MinMax(doc1,doc2,alpha=0.5,Beta=0.5):
    sim1=CSM_P1(doc1,doc2)
    sim2=CSM_P2(doc1,doc2)
    simValue=alpha*max(sim1,sim2)+Beta*min(sim1,sim2)
    return simValue
def BLAB_SM(doc1,doc2):
    sim1=CSMB(doc1,doc2,alpha=0.5,Beta=0.5)# CSMB10
    return sim1
def ZSM(doc1,doc2):
    Dij=Nij=Di=Ni=Nj=Dj=0
    a=set(np.nonzero(doc1)[0])  #indices of non zero elements in doc1
    b=set(np.nonzero(doc2)[0])  #indices of non zero elements in doc2
    intersection=a.intersection(b)# indices where both docs have non zero elements
    intersection=np.array(list(intersection))
    if len(intersection)>0:
      #  prod=np.multiply(doc1[intersection],doc2[intersection])
        Dij=np.dot(doc1[intersection],doc2[intersection])#sum(prod)
    Nij=len(intersection)
    zsm=(Nij*Dij)/(np.sum(doc1)*np.sum(doc2))
    return  zsm
def CSM_P1(doc1,doc2):
    simValue=0 
    if ((not np.any(doc1)) or (not np.any( doc2))):   
        simValue=0  
    else:
        simValue=0
        N=len(doc1)#total_features;
        a=set(np.nonzero(doc1)[0])  
        b=set(np.nonzero(doc2)[0])   
        Nab=len(a.intersection(b))
        F=len(a.union(b))-Nab
        simValue=(1-F/N)
    return simValue
def CSM_P2(doc1,doc2):
    simVal=0
    if ((not np.any(doc1)) or (not np.any( doc2))):   
        simValue=0  
    else:
        simValue=0
        a=set(np.nonzero(doc1)[0])  
        b=set(np.nonzero(doc2)[0])   
        Na=len(a)
        Nb=len(b)
        Nab=len(a.intersection(b))
        simVal=(2*Nab)/(Na+Nb)
    return simVal
def DDSMa(doc1,doc2):
    sim=1-(np.sum(np.abs(doc1-doc2))/np.sum(doc1+doc2))
    return sim
def DDSMb(doc1,doc2):
    sim =1-(np.sum(np.square(doc1-doc2))/np.sum(np.square(doc1+doc2)))
    return sim
def DDSMc(doc1,doc2):
    doc3=np.square(doc1)
    doc4=np.square(doc2)
    sim= 1-(np.sum(np.abs(doc3-doc4))/np.sum(np.square(doc1+doc2)))
    return sim
def EN1_DDSMa(doc1,doc2):
    return (DDSMa(doc1,doc2)*CSM_P1(doc1,doc2))
def EN_DDSMb(doc1,doc2):
    a=set(np.nonzero(doc1)[0])  
    b=set(np.nonzero(doc2)[0])
    SF=len(list(a.intersection(b)))
    N=len(doc1)
    return (DDSMb(doc1,doc2)*(SF+1)/(N+1))
def EN_DDSMc(doc1,doc2):
    a=set(np.nonzero(doc1)[0])  
    b=set(np.nonzero(doc2)[0])
    SF=len(list(a.intersection(b)))
    N=len(doc1)
    return (DDSMc(doc1,doc2)*(SF+1)/(N+1))
def BASM(doc1,doc2):
    return CSM_P2(doc1,doc2) 
def ESTB_SM(doc1,doc2):
    a=set(np.nonzero(doc1)[0])  
    b=set(np.nonzero(doc2)[0])
    intersection=np.array(list(a.intersection(b)))
    comp1=np.array(list(a-b))
    comp2=np.array(list(b-a))
    X,Y,D1,D2,sim=0,0,0,0,0                   
    if len(intersection)>0:
        X=np.sum(doc1[intersection])
        Y=np.sum(doc2[intersection])
        if len(comp1)>0:
            D1=np.sum(doc1[comp1])
        if len(comp2)>0:
            D2=np.sum(doc2[comp2])
        if len(intersection)>0:
            sim=1/(1+((D1/X)+(D2/Y)))
    return sim 
def ESTBSM_Sim2(doc1,doc2):
    sim= (1-ESTB_SM(doc1,doc2))*CSM_P2(doc1,doc2)
    return 1-sim
def ESTB_V1(doc1,doc2):
    return (1-ESTB_SM(doc1,doc2))+CSM_P2(doc1,doc2)
def ESTB_V2(doc1,doc2):
    return (1-ESTB_SM(doc1,doc2))*CSM_P2(doc1,doc2)*(1-ANSM(doc1,doc2))
def ESTB_V3(doc1,doc2):
    estb=1-ESTB_SM(doc1,doc2)
    ansm=ANSM(doc1,doc2)
    return ((estb+ansm)/2)*CSM_P2(doc1,doc2)
def EMX1(doc1,doc2):
    a=set(np.nonzero(doc1)[0])  
    b=set(np.nonzero(doc2)[0])
    intersection=a.intersection(b)
    sim=0
    if len(intersection)>0:
        meanDiff=abs(np.mean(doc1)-np.mean(doc2))
        sim=1/(1+math.exp(-1*meanDiff))
    return sim
def EMX2(doc1,doc2):
    a=set(np.nonzero(doc1)[0])  
    b=set(np.nonzero(doc2)[0])
    intersection=a.intersection(b)
    sim=0
    if len(intersection)>0:
        meanDiff=abs(np.mean(doc1)-np.mean(doc2))
        stdDiff=abs(np.std(doc1)-np.std(doc2))
        sim=1/(1+math.exp(-1*meanDiff*stdDiff))
    return sim 
def EMX7(doc1,doc2):
    sim=EMX1(doc1,doc2)
    if sim>0:
        sim=sim*(1-ESTB_SM(doc1,doc2))*CSM_P2(doc1,doc2)
    return sim 
def EMX13(doc1,doc2):
    sim=EMX2(doc1,doc2)
    if sim>0:
        sim=sim*(1-ESTB_SM(doc1,doc2))*CSM_P2(doc1,doc2)
    return sim 
def PCC_Sim2(doc1,doc2):#distance
    return (1-PCC(doc1,doc2))*CSM_P2(doc1,doc2)
def ANSM(doc1,doc2):
    a=set(np.nonzero(doc1)[0])  #indices of non zero elements in doc1
    b=set(np.nonzero(doc2)[0])  #indices of non zero elements in doc2
    com=np.array(list(a.intersection(b)))
    sim=0
    if len(com)>0:
        sim=np.sum(np.sum(doc1[com]+doc2[com]))/(np.sum(doc1)+np.sum(doc2))
        
    return sim   
def ANSM_V1(doc1,doc2):
    a=set(np.nonzero(doc1)[0])  #indices of non zero elements in doc1
    b=set(np.nonzero(doc2)[0])  #indices of non zero elements in doc2
    SP=len(a.intersection(b))
    N=len(doc1)
    return 1-((1-ANSM(doc1,doc2))*((SP+1)/(N+1)))
def ANSM_V2(doc1,doc2):
    return (1-ANSM(doc1,doc2))*CSM_P2(doc1,doc2)
def ANSM_V3(doc1,doc2):
    sim= ((1-ANSM(doc1,doc2))+CSM_P2(doc1,doc2))/2
    return sim
def KL(a, b):
    return entropy(a,b)

def MSTB_SM(doc1,doc2):
    a=set(np.nonzero(doc1)[0])  
    b=set(np.nonzero(doc2)[0])
    intersection=np.array(list(a.intersection(b)))
    sim=0
    if len(intersection)>0:
        ints=np.sum(np.intersect1d(doc1,doc2))
        D1=np.sum(np.unique(doc1))-ints
        D2=np.sum(np.unique(doc2))-ints
        X,Y=0,0  
        X=np.sum(doc1[intersection])
        Y=np.sum(doc2[intersection])
        a=np.array(list(a))
        b=np.array(list(b))
        Z1,Z2=0,0
        Z1=np.sum(doc1[a])
        Z2=np.sum(doc2[b]) 
        sim=((X*Y)/(Z1*Z2))*(1-((D1*D2)/(Z1*Z2)))
    return sim 
def STB_SM(doc1,doc2):
    a=set(np.nonzero(doc1)[0])  
    b=set(np.nonzero(doc2)[0])
    intersection=np.array(list(a.intersection(b)))
    comp1=a-b
    comp2=b-a   
    comp1=np.array(list(comp1))
    comp2=np.array(list(comp2))
    a=np.array(list(a))
    b=np.array(list(b))
    X,Y,D1,D2,Z1,Z2,sim=0,0,0,0,0,0,0
    if len(intersection)>0:
        X=np.sum(doc1[intersection])
        Y=np.sum(doc2[intersection])
    if len(comp1)>0:
        D1=np.sum(doc1[comp1])
    if len(comp2)>0:
        D2=np.sum(doc2[comp2])
    if len(a)>0:
        Z1=np.sum(doc1[a])
    if len(b)>0:
        Z2=np.sum(doc2[b]) 
    if Z1!=0 and Z2!=0:
        sim=((X*Y)/(Z1*Z2))*(1-((D1*D2)/(Z1*Z2)))
    return sim
def DSM(doc1,doc2,var):
    lemda=1
    a=set(np.nonzero(doc1)[0])  #indices of non zero elements in doc1
    b=set(np.nonzero(doc2)[0])  #indices of non zero elements in doc2
    intersection=a.intersection(b) # indices where both docs have non zero elements
    union=a.union(b) # indices where either doc has non zero elements
    doc1=np.array(doc1)
    doc2=np.array(doc2)
    Nstar=0
    intersection=np.array(list(intersection))
    if (len(intersection)>0):
        term1=np.exp(-1*( doc1[intersection]-doc2[intersection] )/var[intersection])
        Nstar=sum(0.5* (1+term1)) 
    else:
        Nstar=lemda* -1 
    Nunion=len(union)
    dsm=0
    if Nunion!=0:
        dsm=((Nstar/Nunion)+lemda)/(1+lemda)
   
    return dsm
def TA(doc1,doc2):
    a=np.sqrt(doc1.dot(doc1))
    b=np.sqrt(doc2.dot(doc2))
    dot=np.dot(doc1,doc2)**2
    sim=0
    if a<=b:
        sim=dot/(a*(b**3))
    else:
        sim=1-(dot/(b*(a**3)))
    return sim


######################Enhnaced Measures#################################################
def EExtendedJaccard(a,b):
    vector1=set(np.where(a!=0)[0])
    vector2=set(np.where(b!=0)[0])
    dot=len(vector1.intersection(vector2))
    sum1=len(vector1)
    sum2=len(vector2)
    denom=math.sqrt(sum1)+math.sqrt(sum2)-dot
    if(denom!=0):
        return 1.0 - (float(dot)/(denom))
    else:
        return -1
    
def EPairwise(a,b):
    percentage=1 #100 percent
    K1=np.count_nonzero(a)
    K2=np.count_nonzero(b)
    k=percentage*min(K1,K2)
    setA=set(np.argpartition(a, len(a)-1 - k)[-k:])
    setB=set(np.argpartition(b, len(b) -1- k)[-k:])
    union=np.array(list(setA.union(setB)))
    elementsA=a[union]
    elementsB=b[union]
    return distance.cosine(elementsA, elementsB)

def EJS(a, b):
    p = a/ np.sum(a)
    q = b/ np.sum(b)
    m = np.add(p,q) / 2
    return (entropy(p, m) + entropy(q, m)) / 2

def EDice(doc1,doc2):
    a=set(list(np.nonzero(doc1!=0)[0]))  #indices of non zero elements in doc1
    b=set(list(np.nonzero(doc2!=0)[0]))  #indices of non zero elements in doc2
    intr=len(a.intersection(b))
    aComp=len(a-b)
    bComp=len(b-a)
    sim=0
    if (intr+aComp+bComp)!=0:
        sim=2*(intr/(2*(intr+aComp+bComp)))
    return sim
def EExtendedDice(doc1, doc2):
    a=set(list(np.nonzero(doc1!=0)[0]))  #indices of non zero elements in doc1
    b=set(list(np.nonzero(doc2!=0)[0]))  #indices of non zero elements in doc2
    intr=len(a.intersection(b))
    sim=(2*intr)/(len(a)**2 + len(b)**2)
    return sim
def EPDSM(doc1,doc2):
    a=set(np.nonzero(doc1!=0)[0])  #indices of non zero elements in doc1
    b=set(np.nonzero(doc2!=0)[0])  #indices of non zero elements in doc2
    intersection=np.sum(np.minimum(doc1,doc2))
    union=np.sum(np.maximum(doc1,doc2))
    PF=len(a.intersection(b))
    M=len(doc1)
    AF=M-len(a.union(b))
    psdm=(intersection/union)*((PF+1)/(M-AF+1))
    return psdm
def esmtp(doc1,doc2,var):
    lemda=1
    a=set(list(np.nonzero(doc1 != 0)[0]))  #indices of non zero elements in doc1
    b=set(list(np.nonzero(doc2 != 0)[0]))  #indices of non zero elements in doc2
    intersection=a.intersection(b) # indices where both docs have non zero elements
    union=a.union(b) # indices where either doc has non zero elements
    l1=len(a-intersection) # doc1 !=0 and doc2=0
    l2=len(b-intersection) # doc1 =0 and doc2!=0
    Nstar=0
    intersection=np.array(list(intersection))
    if (len(intersection)>0):
        term1=np.exp(-1*np.square(( doc1[intersection]-doc2[intersection] )/var[intersection]))
        Nstar=np.sum(0.5* (1+term1)) +lemda* -1 *(l1+l2)
    else:
        Nstar=lemda* -1 *(l1+l2)   
    Nunion=len(intersection)+l1+l2
    smtp=((Nstar/Nunion)+lemda)/(1+lemda)
    return smtp
def ENSMT(doc1,doc2):
    Dij=Nij=Di=Ni=Nj=Dj=0
    a=set(list(np.nonzero(doc1 != 0)[0]))  #indices of non zero elements in doc1
    b=set(list(np.nonzero(doc2 != 0)[0]))  #indices of non zero elements in doc2
    intersection=a.intersection(b)# indices where both docs have non zero elements
    a=np.array(list(a-intersection)) 
    b=np.array(list(b-intersection))
    intersection=np.array(list(intersection))
    if len(intersection)>0:
      #  prod=np.multiply(doc1[intersection],doc2[intersection])
        Dij=np.dot(doc1[intersection],doc2[intersection])#sum(prod)
    if len(a)>0:
        Di=np.sum(doc1[a])
    if len(b)>0:
        Dj=np.sum(doc2[b])
    Nij=len(intersection)
    Ni=len(a)
    Nj=len(b)
    Nsmt=0
    if (Ni*Di+Dj*Nj)!=0:
        Nsmt=(Nij*Dij)/(Ni*Di+Dj*Nj)
    return Nsmt

def EBLAB_SM(doc1,doc2):
    return 0.5*(ECSM_P1(doc1,doc2)+ECSM_P2(doc1,doc2))
    '''
    if dataset=="reuters":
        sim1=ECSMB_MinMax(doc1,doc2,alpha=0.7,Beta=0.3)#CSMB12
    else:
        sim1=ECSMB(doc1,doc2,alpha=0.9,Beta=0.1)# CSMB10
    
    return sim1
    '''
def EESTB_SM(doc1,doc2):
    a=set(list(np.nonzero(doc1 != 0)[0]))  #indices of non zero elements in doc1
    b=set(list(np.nonzero(doc2 != 0)[0]))  #indices of non zero elements in doc2
    intersection= np.array(list(a.intersection(b)))
    comp1=np.array(list(a-b))
    comp2=np.array(list(b-a))
    D1=D2=sim=0                   
    if len(intersection)>0:
        X=np.sum(doc1[intersection])
        Y=np.sum(doc2[intersection])
        if len(comp1)>0:
            D1=np.sum(doc1[comp1])
        if len(comp2)>0:
            D2=np.sum(doc2[comp2])
        sim=1/(1+((D1/X)+(D2/Y)))
    return sim


def ECSM_P2(doc1,doc2):
    a=set(list(np.nonzero(doc1 != 0)[0]))  #indices of non zero elements in doc1
    b=set(list(np.nonzero(doc2 != 0)[0]))  #indices of non zero elements in doc2NSMT
    sim=0
    if (len(a)+len(b))!=0:
        sim=(2*len(a.intersection(b)))/(len(a)+len(b))
    return sim



def EEMX1(doc1,doc2):
    a=set(np.nonzero(doc1!=0)[0])  
    b=set(np.nonzero(doc2!=0)[0])
    intersection=a.intersection(b)
    intersection=a.intersection(b)
    sim=0
    if len(intersection)>0:
        meanDiff=abs(np.mean(doc1)-np.mean(doc2))
        sim=1/(1+math.exp(-1*meanDiff))
    return sim


def EEMX2(doc1,doc2):
    a=set(np.nonzero(doc1!=0)[0])  
    b=set(np.nonzero(doc2!=0)[0])
    intersection=a.intersection(b)
    sim=0
    if len(intersection)>0:
        meanDiff=abs(np.mean(doc1)-np.mean(doc2))
        stdDiff=abs(np.std(doc1)-np.std(doc2))
        sim=1/(1+math.exp(-1*meanDiff*stdDiff))
    return sim 

def EEMX7(doc1,doc2):
    sim=EEMX1(doc1,doc2)
    if sim>0:
        sim=sim*(1-EESTB_SM(doc1,doc2))*ECSM_P2(doc1,doc2)
    return sim
def EEMX13(doc1,doc2):
    sim=EEMX2(doc1,doc2)
    if sim>0:
        sim=sim*(1-EESTB_SM(doc1,doc2))*ECSM_P2(doc1,doc2)
    return sim 

def EMSTB_SM(doc1,doc2):
    a=np.nonzero(doc1 != 0)[0]  #indices of non zero elements in doc1
    b=np.nonzero(doc2 != 0)[0]  #indices of non zero elements in doc2
    newDoc1=doc1[a]
    newDoc2=doc2[b]
    intersection=np.intersect1d(a,b)
    sim=0
    if len(intersection)>0:
        ints=np.sum(np.intersect1d(doc1,doc2))
        D1=np.sum(np.unique(newDoc1))-ints
        D2=np.sum(np.unique(newDoc2))-ints 
        X=np.sum(doc1[intersection])
        Y=np.sum(doc2[intersection])
        Z1=np.sum(newDoc1)
        Z2=np.sum(newDoc2) 
        sim=((X*Y)/(Z1*Z2))*(1-((D1*D2)/(Z1*Z2)))
    return sim 

def ECSM_P1(doc1,doc2):
    simValue=0
    N=len(doc1)#total_features;
    a=set(list(np.nonzero(doc1 != 0)[0]))  #indices of non zero elements in doc1
    b=set(list(np.nonzero(doc2 != 0)[0]))  #indices of non zero elements in doc2NSMT
    Nab=len(a.intersection(b))
    F=len(a.union(b))-Nab
    simValue=(1-F/N)
    return simValue
def DDSMa(doc1,doc2):
    return 1-(np.sum(np.abs(doc1-doc2))/np.sum(doc1+doc2))
def DDSMb(doc1,doc2):
    return 1-(np.sum(np.square(doc1-doc2))/np.sum(np.square(doc1+doc2)))
def DDSMc(doc1,doc2):
    doc3=np.square(doc1)
    doc4=np.square(doc2)
    return 1-(np.sum(np.abs(doc3-doc4))/np.sum(np.square(doc1+doc2)))

def EEN1_DDSMa(doc1,doc2):
    return DDSMa(doc1,doc2)*ECSM_P1(doc1,doc2)
def EEN_DDSMb(doc1,doc2):
    a=set(list(np.nonzero(doc1 != 0)[0]))  #indices of non zero elements in doc1
    b=set(list(np.nonzero(doc2 != 0)[0]))  #indices of non zero elements in doc2
    SF=len(a.intersection(b))
    N=len(doc1)
    return DDSMb(doc1,doc2)*(SF+1)/(N+1)
def EEN_DDSMc(doc1,doc2):
    a=set(list(np.nonzero(doc1 != 0)[0]))  #indices of non zero elements in doc1
    b=set(list(np.nonzero(doc2 != 0)[0]))  #indices of non zero elements in doc2
    SF=len(a.intersection(b))
    sim=1-(DDSMc(doc1,doc2)*(SF+1)/(len(doc1)+1))
    return sim


def EANSM(doc1,doc2):
    a=np.nonzero(doc1 != 0)[0] #indices of non zero elements in doc1
    b=np.nonzero(doc2 != 0)[0]  #indices of non zero elements in doc2
    com=np.intersect1d(a,b)
    sim=0
    if len(com)>0:
        sim=np.sum(doc1[com]+doc2[com])/np.sum(doc1+doc2)
    return sim  
def EANSM_V3(doc1,doc2):
    return (EANSM(doc1,doc2)+ECSM_P2(doc1,doc2))/2

def EZSM(doc1,doc2):
    Dij=Nij=Di=Ni=Nj=Dj=0
    a=np.nonzero(doc1 != 0)[0]  #indices of non zero elements in doc1
    b=np.nonzero(doc2 != 0)[0]  #indices of non zero elements in doc2
   # sum1=np.sum(doc1[a])
    #sum2=np.sum(doc2[b])
    a=set(list(a))
    b=set(list(b)) 
    intersection=a.intersection(b)# indices where both docs have non zero elements
    intersection=np.array(list(intersection))
    Nij=len(intersection)
    if Nij>0:
        Dij=np.dot(doc1[intersection],doc2[intersection])#sum(prod)
    zsm=(Nij*Dij)/(np.sum(doc1)*np.sum(doc2))
    return zsm
def EEnhancedJaccard(a, b):#similarity
    a=set(np.nonzero(a!=0)[0])  #indices of non zero elements in doc1
    b=set(np.nonzero(b!=0)[0])  #indices of non zero elements in doc2
    union=a.union(b)
    intersection=a.intersection(b)
    sim=0
    if len(union)!=0:
        sim=len(intersection)/len(union)#similarity
    return sim
def esimIT(a,b):
    p1= np.divide(a,termOcc) 
    p2= np.divide(b,termOcc)
    minVal=np.minimum(p1,p2)
    pi=np.log((np.array(docOcc)/totalDocs))
    sIT=(2*np.sum(np.multiply(minVal,pi)))/((np.sum(np.multiply(p1,pi)))+(np.sum(np.multiply(p2,pi))))
    return sIT
def STB_SM_new(doc1,doc2):
    a=set(list(np.nonzero(doc1 != 0)[0]))  #indices of non zero elements in doc1
    b=set(list(np.nonzero(doc2 != 0)[0]))  #indices of non zero elements in doc2
    intersection=np.array(list(a.intersection(b)))
    comp1=a-b
    comp2=b-a   
    comp1=np.array(list(comp1))
    comp2=np.array(list(comp2))
    X,Y,D1,D2,Z1,Z2,sim=0,0,0,0,0,0,0
    if len(intersection)>0:
        X=np.sum(doc1[intersection])
        Y=np.sum(doc2[intersection])
    if len(comp1)>0:
        D1=np.sum(doc1[comp1])
    if len(comp2)>0:
        D2=np.sum(doc2[comp2])
    Z1=np.sum(doc1)
    Z2=np.sum(doc2) 
    if Z1!=0 and Z2!=0:
        sim=((X*Y)/(Z1*Z2))*(1-((D1*D2)/(Z1*Z2)))
    return sim
def EBASM(doc1,doc2):
    return ECSM_P2(doc1,doc2) 
def EISC(doc1,doc2): 
    dot=np.sum(np.sqrt(np.multiply(doc1,doc2)))
    isc=dot /( math.sqrt(np.linalg.norm(doc1, ord=1))*math.sqrt(np.linalg.norm(doc2, ord=1)))
    return isc

#SP equations
def ESP(doc1,doc2):
    a=set(list(np.nonzero(doc1!=0)[0]))  #indices of non zero elements in doc1
    b=set(list(np.nonzero(doc2!=0)[0]))  #indices of non zero elements in doc2
    nonzeroTerm=list(a.intersection(b))  #indices where both docs have non zero elemments
    d1=doc1[nonzeroTerm] #doc1 values of doc1 intersection  doc2
    d2=doc2[nonzeroTerm] #doc2 values of doc1 intersection  doc2
    minArr=np.minimum(d1,d2) #minimum values  of d1 and d2
    maxArr=np.maximum(d1,d2) #maximum values  of d1 and d2
    ln=len(nonzeroTerm)
    docCount=np.zeros(ln)
    aData=allData[:,nonzeroTerm] #extracting data with only feature indices of doc1 intersection  doc2
    for ti in range(0,ln):
        docCount[ti]=count_values_in_range(aData[:,ti], minArr[ti], maxArr[ti]) #count values which lies between min and max
    #norm factor which is ist part of equation 6 in paper
    normFactor= len(a.union(b))#norm factor equal to length of doc1 union doc2
    dCount=np.array(docCount[np.nonzero(docCount!=0)[0]])# get all non zero values between min and max
    SP_val=0
    if(normFactor!=0):
        SP_val=np.sum(np.log(totalDocs/dCount)) #2nd part in equation 6 in paper
        SP_val = (SP_val/normFactor) #equation 6 in paper
    return SP_val
def ENSMT_BASM(doc1,doc2):
    return ENSMT(doc1,doc2)*BASM(doc1,doc2)
    
def PCC_BASM(doc1,doc2):
    return PCC(doc1,doc2)*BASM(doc1,doc2)


class SimMeaure:

    #constructor

    def __init__(self,k = 1,metric="euclidean",termOccurance=None, docOccurance=None):

        
        self.k=k
        #print ("KNN",self.k)
        self.metric=metric
        self.trainingData=[]
        self.trainLabels=[]
        self.smtp=None
        self.termOccurance=termOccurance
        self.docOccurance=docOccurance
         
    
         

    def fit(self, training_data, trainLabels ):
        self.trainingData=training_data
        self.trainLabels=trainLabels
        
            
       
    def predict(self, testData):
        train=self.trainingData
        var=np.zeros(train.shape[1])
        if(self.metric=="smtp" or  self.metric=="esmtp" or  self.metric=="DSM"):
            var=np.var(train,axis=0)
            print("Vrainace is",var)
        distList=["KL","extendedJaccard","bhatta","Euclidean","Cosine","Jaccard","JS","EJS","Dice",
                  "Pairwise","EPairwise","Manhattan","EnhancedJaccard","EEnhancedJaccard","eextendedJaccard","EJS","Minkowski"]#distance
        func=globals()[self.metric]
        predLabel=[]
        kList=[1,3,5,9,15,30,45,70,90,120]
        for kk in range(0,len(kList)):
            temp=[]
            predLabel.append(temp)
            ''''''
        distMatrix=[]         
        for i in(range(0,len(testData))):
            #print(i)
            dist=[]
            for j in(range(0,len(train))):
                if ((not np.any(testData[i])) or (not np.any( train[j]))):
                    if(self.metric in distList):
                        dist.append(-1)
                    else:
                        dist.append(0)
                else:
                    if(self.metric=="smtp" or self.metric=="smtp_improved" or self.metric=="esmtp" or self.metric=="DSM"):
                        dist.append(func(testData[i],train[j],var)) 
                    elif(self.metric=="SP"):
                        doc1=testData[i]
                        doc2=train[j]
                        nonzeroDoc1=set(np.nonzero(doc1)[0])
                        nonzeroDoc2=set(np.nonzero(doc2)[0])
                        nonzeroTerm=list(nonzeroDoc1.intersection(nonzeroDoc2))
                        minArr=np.minimum(doc1[nonzeroTerm],doc2[nonzeroTerm])
                        maxArr=np.maximum(doc1[nonzeroTerm],doc2[nonzeroTerm])
                        ln=len(nonzeroTerm)
                        aData=allData[:,nonzeroTerm]
                        docCount=np.zeros(ln)
                        for ti in range(0,ln):
                            tData=pd.Series(aData[:,ti])
                            docCount[ti]=count_values_in_range(tData, minArr[ti], maxArr[ti])
                        dist.append(SP(testData[i],train[j],docCount,totalDocs))
                    else:
                        dist.append(func(testData[i], train[j]))
            flag=-1
            dist=list(dist)
            if(self.metric in distList):
                dist=[(1/(x+0.0001)) for x in dist]
                flag=1
            distMatrix.append(dist)
        return distMatrix


def groupData(labels,categories):

    print (categories)
    groups=[]
    for i in range(0,len(categories)):
        groups.append([0,0,0])
    totalDocs=len(labels)
    print (totalDocs)
    for i in range(0,totalDocs):
        tmp=(categories.index(labels[i]))
        groups[tmp].append(i)
    for i in range(0,len(categories)):
        del (groups[i])[0:3]
    return groups

class CNN() : # to take preprocessed data , pass them into model and print results
    def __init__ (self ,  x_train  , x_test , y_train , y_test ):
        self.x_train=x_train
        self.x_test=x_test
        self.y_train=y_train
        self.y_test=y_test
    def fit(self,x_train  , y_train  , x_test, y_test , outputdim) :         
      #Fitting CNN Model
        config = tf.compat.v1.ConfigProto( device_count = {'GPU': 2 , 'CPU': 6} ) 
        sess = tf.compat.v1.Session(config=config) 
        tf.compat.v1.keras.backend.set_session(sess)
        model = Sequential()
        input_dim = x_train.shape[1]  # Number of features
        #micro_f1 = metrics.F1Score(num_classes=input_dim , average='micro')
        y_train = np.asarray(train_labels)
        y_test = np.asarray(test_labels)
        x_train=x_train.reshape(x_train.shape[0],x_train.shape[1],1)
        x_test=x_test.reshape(x_test.shape[0],x_test.shape[1],1)
        

        model.add(Conv1D(30, kernel_size=5, strides=1,activation='relu',input_shape = ( x_train.shape[1],1)))
        #model.add(Dropout(0.5))
        model.add(MaxPooling1D(pool_size=1))
        #model.add(Conv1D(100, kernel_size=1,activation='relu'))
       # model.add(Dropout(0.5))
        #model.add(MaxPooling1D(pool_size=1))
        model.add(Flatten())
        
        model.add(Dense(30, activation='relu',kernel_regularizer='l2'))
        model.add(Dropout(0.5))
        model.add(Dense(outputdim, activation='softmax'))
        model.summary()
        #model.add(Conv1D(filters=64, kernel_size=3,padding='same', activation='relu', input_shape=(1,x_train.shape[1])))
        #model.add(Conv1D(filters=64, kernel_size=3, activation='relu'))
        #
        #
        
       # model.add(Dense(100, activation='relu'))
        #model.add(Dense(outputdim, activation='softmax'))
        #sgd = SGD(lr=0.0001)
        model.compile(loss='sparse_categorical_crossentropy', optimizer='adam' ,metrics=['accuracy'])
        
        history = model.fit(x_train, y_train,
                    epochs=100,
                    validation_data=(x_test, y_test),
                     verbose=1)
         #Finally testing the model & getting accuracy metrics
        model.summary()
        loss,acc = model.evaluate(x_test, y_test, verbose=1)
        y_pred1 = model.predict(x_test)
        predicts = np.max(y_pred1,axis=1) 
        sess.close()
        return np.argmax(y_pred1,axis=1) ,y_pred1
def ECSM_P1(doc1,doc2):
    simValue=0
    N=len(doc1)#total_features;
    a=set((np.nonzero(doc1 != 0)[0]).tolist()) #indices of non zero elements in doc1
    b=set((np.nonzero(doc2 != 0)[0]).tolist()) #indices of non zero elements in doc2NSMT
    Nab=len(a.intersection(b))
    F=len(a.union(b))-Nab
    simValue=(1-F/N)
    return simValue
def ECSM_P2(doc1,doc2):
    a=set((np.nonzero(doc1 != 0)[0]).tolist()) #indices of non zero elements in doc1
    b=set((np.nonzero(doc2 != 0)[0]).tolist()) #indices of non zero elements in doc2NSMT
    sim=0
    if (len(a)+len(b))!=0:
        sim=(2*len(a.intersection(b)))/(len(a)+len(b))
    return sim

def EBLAB_SM(doc1,doc2):
    return 0.5*(ECSM_P1(doc1,doc2)+ECSM_P2(doc1,doc2))

def ESTB_SM(doc1,doc2):
    a=set(np.nonzero(doc1)[0])  
    b=set(np.nonzero(doc2)[0])
    intersection=np.array(list(a.intersection(b)))
    comp1=np.array(list(a-b))
    comp2=np.array(list(b-a))
    X,Y,D1,D2,sim=0,0,0,0,0                   
    if len(intersection)>0:
        X=np.sum(doc1[intersection])
        Y=np.sum(doc2[intersection])
        if len(comp1)>0:
            D1=np.sum(doc1[comp1])
        if len(comp2)>0:
            D2=np.sum(doc2[comp2])
        if len(intersection)>0:
            sim=1/(1+((D1/X)+(D2/Y)))
    return sim 
def ESP(doc1,doc2):
    a=set(list(np.nonzero(doc1!=0)[0]))  #indices of non zero elements in doc1
    b=set(list(np.nonzero(doc2!=0)[0]))  #indices of non zero elements in doc2
    nonzeroTerm=list(a.intersection(b))  #indices where both docs have non zero elemments
    d1=doc1[nonzeroTerm] #doc1 values of doc1 intersection  doc2
    d2=doc2[nonzeroTerm] #doc2 values of doc1 intersection  doc2
    minArr=np.minimum(d1,d2) #minimum values  of d1 and d2
    maxArr=np.maximum(d1,d2) #maximum values  of d1 and d2
    ln=len(nonzeroTerm)
    docCount=np.zeros(ln)
    aData=allData[:,nonzeroTerm] #extracting data with only feature indices of doc1 intersection  doc2
    for ti in range(0,ln):
        docCount[ti]=count_values_in_range(aData[:,ti], minArr[ti], maxArr[ti]) #count values which lies between min and max
    #norm factor which is ist part of equation 6 in paper
    normFactor= len(a.union(b))#norm factor equal to length of doc1 union doc2
    dCount=np.array(docCount[np.nonzero(docCount!=0)[0]])# get all non zero values between min and max
    SP_val=0
    if(normFactor!=0):
        SP_val=np.sum(np.log(totalDocs/dCount)) #2nd part in equation 6 in paper
        SP_val = (SP_val/normFactor) #equation 6 in paper
    return SP_val

def esmtp(doc1,doc2,var):
    lemda=1
    a=set(list(np.nonzero(doc1 != 0)[0]))  #indices of non zero elements in doc1
    b=set(list(np.nonzero(doc2 != 0)[0]))  #indices of non zero elements in doc2
    intersection=a.intersection(b) # indices where both docs have non zero elements
    union=a.union(b) # indices where either doc has non zero elements
    l1=len(a-intersection) # doc1 !=0 and doc2=0
    l2=len(b-intersection) # doc1 =0 and doc2!=0
    Nstar=0
    intersection=np.array(list(intersection))
    if (len(intersection)>0):
        term1=np.exp(-1*np.square(( doc1[intersection]-doc2[intersection] )/var[intersection]))
        Nstar=np.sum(0.5* (1+term1)) +lemda* -1 *(l1+l2)
    else:
        Nstar=lemda* -1 *(l1+l2)   
    Nunion=len(intersection)+l1+l2
    smtp=((Nstar/Nunion)+lemda)/(1+lemda)
    return smtp
def classify(metric='Cosine',termOccurance=None, docOccurance=None):
    global time1
    global time2
    time1= time.time()
    
    y_pred =NBCombined(train_data, train_labels,test_data,metric)
    time2= time.time()
    
    for i in range(0,1):
        #Accuracy
    
        accuracy=accuracy_score(test_labels, y_pred)
        
        #Macro Precision
        
        macroP=precision_score(test_labels, y_pred,average='macro')
        
        #Micro Precision
        
        microP=precision_score(test_labels, y_pred,average='micro')
        
        #Macro Recall
        
        macroR=recall_score(test_labels, y_pred,average='macro')
        
        #Micro Recall
        
        microR=recall_score(test_labels, y_pred,average='micro')
        
        
        fMeasure=f1_score(test_labels, y_pred,average='macro')
       # PrintDetails(metric=metric,time=str(timedelta(seconds=(time2-time1))),measure="F Measure",Arr=fMeasure)
        
        m_fMeasure=f1_score(test_labels, y_pred,average='micro')
       # PrintDetails(metric=metric,time=str(timedelta(seconds=(time2-time1))),measure="F Measure",Arr=fMeasure)
        
        #PrintDetails(metric=metric,time=str(timedelta(seconds=(time2-time1))),measure="g Measure",Arr=gMeasure)
      
        test = label_binarize(test_labels, classes=categories)
        pred = label_binarize( y_pred, classes=categories)
        
        #roc
        roc=roc_auc_score(test, pred)
    #Accuracy
    accuracy_avg.append(accuracy)
    #Precision
    macroP_avg.append(macroP)
    microP_avg.append(microP)
    #recall
    macroR_avg.append(macroR)
    microR_avg.append(microR)
    #F measure
    macroFMeasure_avg.append(fMeasure)
    microFMeasure_avg.append( m_fMeasure)
    #Roc
    roc_avg.append(roc)

def PrintDetails(metric="smtp",time=None,measure= "Accuracy",Arr=None):
    x = PrettyTable()
    kList=[1,3,5,9,15,30,45]
    x.field_names = ["split","DataSet1"]
    print("metric",metric)
    print("time",time)
    print("measure",measure)
    tables.write("metric\t"+str(metric)+"\n")
    tables.write("time\t"+str(time)+"\n")
    tables.write("measure\t"+str(measure)+"\n")
    average=0
    for i in range(0,len(Arr)):
        x.add_row([i+1,Arr[i]]) 
        average+=Arr[i]
    x.add_row(["Average",average/len(Arr)])   
    tables.write(str(x))
    print (x)
def NBCombined(train_data, train_labels,test_data,metric):
    #prediction of NB on test data
    classes=list(set(train_labels))
    global prob
    prob1=prob[split]
    y_pred=[]
    print("prob",len(prob1))
    if len(prob1)==0:
        print("processing")
        cnn = CNN(train_data, train_labels,test_data,test_labels)
        y_pred,prob[split] = cnn.fit(train_data, train_labels,test_data,test_labels,len(classes))
        #y_pred = np.max(y_pred1,axis=1)
    if metric=="Base":
        return y_pred

    #y_pred = classifier.predict(test_data)
    classifier =SimMeaure(k=1,metric=metric)#,termOccurance=termOccurance,docOccurance=docOccurance)  
    classifier.fit(train_data, train_labels)
    distMatrix = classifier.predict(test_data) 
    print("Dist Mat shape", len(distMatrix))
    print("Element shape", len(distMatrix[0]))
    distList=[]
    predLabels=[]
    nn=10
    prob1=np.array(prob1)
    print(prob1.shape)
    indices=[]
    for cl in range(0,len(classes)):
            indices.append([l for l in range(0,len(train_labels)) if train_labels[l]==classes[cl]])
    
    for tst in range(0,test_data.shape[0]):
        probNb=np.array(prob1[tst,:])
        simAvg=[]
        simValue=np.array(distMatrix[tst])
        
        #neigh_labels=np.array(train_labels)[neigh]
        for cl in range(0,len(classes)):
            cl_ind=indices[cl]
            sim=simValue[cl_ind]
            if nn<=len(sim):
                neigh= np.argpartition(np.array(sim), len(sim) - nn)[-nn:]
            else:
                nnn=len(sim)
                neigh= np.argpartition(np.array(sim), len(sim) - nnn)[-nnn:]
            avg=np.nansum(sim[[neigh]])
            simAvg.append(avg)
        simAvg=(np.array(simAvg))/np.nansum(simAvg)
        #print(probNb)
        totalValue=np.add(probNb, simAvg)
       # totalValue=simAvg
        #print("combined value is",totalValue)
        lblInd=np.where(totalValue == np.max(totalValue))
        ind1=(lblInd[0])[0]
       # print(ind1)
       # print(lbl)
        predLabels.append(ind1)      

    return predLabels
dataset='Newsgroup'
count=0
documents=[]
labels=[]
rawData=[]
token_dict = dict()
documents,labels= loadNewsgroupData(documents,labels)
print(len(documents))
categories=list(set(labels))
totalDocs= len(documents)
print (totalDocs)
stopwords = stopwords.words('english')
tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')
vocabulary = set()
term_docs=[]
terms=[]
totalDocs= len(documents)
print (len(documents))
print ("vectorize")
tfidf = TfidfVectorizer(tokenizer=tokenize1)
print ("fit transform")
tfs = tfidf.fit_transform(documents)
#sorted_scores=display_scores(tfidf, tfs)
#groups=groupData(labels,categories) 
#n=len(sorted_scores)  
arr=np.array(tfs.todense())
n=arr.shape[1]
allData=np.array(arr)
#,
measures=["Base","Euclidean","Manhattan","Cosine","Jaccard", "bhatta","EPairwise" ,"EPDSM","PCC","STB_SM_new",
          "esmtp","EISC","EDice","ESP","EBLAB_SM"]
global prob
prob=[]
labels=np.array(labels)
lab_enc = LabelEncoder()
labels = lab_enc.fit_transform(labels)
k_splits=5
for ks in range(0,k_splits):
    prob.append([])
    
kf = StratifiedKFold(n_splits=k_splits)
labels=np.array(labels)
var=0
categories=list(set(set(labels)))
categories.sort()
print(categories)
global time1
global time2
time1,time2=0,0
split=0

for met in measures:
    print("###############")
    fname='table_'+dataset+'_CNN_'+met+'_Tfidf_5RE.txt'
    tables = open(fname, 'w')
    tables.write("No. of features\t"+str(n)+"\n")
    print("###############")
    accuracy_avg=[]
    macroP_avg=[]
    microP_avg=[]
    macroR_avg=[]
    microR_avg=[]
    macroFMeasure_avg=[]
    microFMeasure_avg=[]
    roc_avg=[]
    split=0
    if met=="esimIT":
        rows,cols=allData.shape
        termOcc=np.sum(allData,axis=0)
        docOcc=np.count_nonzero(allData,axis=0)
    if met=="smtp" or met=="esmtp" or met=="DSM":
        var1=np.var(arr,axis=0).reshape(-1,1).ravel()
        var=np.asarray(var1).ravel()
    rand_state=[0,1,10,42,30]
    for i in range(0,k_splits):
        xTrain, xTest, yTrain, yTest = train_test_split(arr, labels, test_size = 0.3, random_state = rand_state[i],stratify=labels)
        train_data=np.array(xTrain)
        test_data=np.array(xTest)
        train_labels=yTrain
        test_labels=yTest 
        classify(metric=met) 
        split+=1

    #time2=time.time()
    #Accuracy
    PrintDetails(metric=met,time=str(timedelta(seconds=(time2-time1))),measure="Accuracy",Arr=accuracy_avg)
    #Precision
    PrintDetails(metric=met,time=str(timedelta(seconds=(time2-time1))),measure="Macro Precision",Arr=macroP_avg)
    PrintDetails(metric=met,time=str(timedelta(seconds=(time2-time1))),measure="Micro Precision",Arr=microP_avg)
    #Recall
    PrintDetails(metric=met,time=str(timedelta(seconds=(time2-time1))),measure="Macro Recall",Arr=macroR_avg)
    PrintDetails(metric=met,time=str(timedelta(seconds=(time2-time1))),measure="Micro Recall",Arr=microR_avg)
    #f measure
    PrintDetails(metric=met,time=str(timedelta(seconds=(time2-time1))),measure="F Measure",Arr=macroFMeasure_avg)

    #f measure
    PrintDetails(metric=met,time=str(timedelta(seconds=(time2-time1))),measure="Micro F Measure",Arr=microFMeasure_avg)

    #roc
    PrintDetails(metric=met,time=str(timedelta(seconds=(time2-time1))),measure="ROC",Arr=roc_avg)
    tables.close()
    print("###############")
# Out:
# labels [2 4 4 ... 5 0 4]
# 5676
# 5676
# 5676
# vectorize
# fit transform
# [0, 1, 2, 3, 4, 5]
# ###############
# ###############
# prob 0
# processing
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 37561, 30)         180
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 37561, 30)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 1126830)           0
# _________________________________________________________________
# dense (Dense)                (None, 30)                33804930
# _________________________________________________________________
# dropout (Dropout)            (None, 30)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 186
# =================================================================
# Total params: 33,805,296
# Trainable params: 33,805,296
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 125/125 [==============================] - 119s 955ms/step - loss: 1.9655 - accuracy: 0.5371 - val_loss: 2.0557 - val_accuracy: 0.6136
# Epoch 2/100
# 125/125 [==============================] - 110s 882ms/step - loss: 2.1717 - accuracy: 0.7136 - val_loss: 2.2421 - val_accuracy: 0.8867
# Epoch 3/100
# 125/125 [==============================] - 108s 862ms/step - loss: 2.4391 - accuracy: 0.7795 - val_loss: 2.3549 - val_accuracy: 0.9060
# Epoch 4/100
# 125/125 [==============================] - 114s 909ms/step - loss: 2.5962 - accuracy: 0.7936 - val_loss: 2.6158 - val_accuracy: 0.8767
# Epoch 5/100
# 125/125 [==============================] - 110s 881ms/step - loss: 2.8159 - accuracy: 0.7979 - val_loss: 2.7176 - val_accuracy: 0.8967
# Epoch 6/100
# 125/125 [==============================] - 108s 868ms/step - loss: 2.8849 - accuracy: 0.7971 - val_loss: 2.8239 - val_accuracy: 0.8955
# Epoch 7/100
# 125/125 [==============================] - 110s 883ms/step - loss: 3.0201 - accuracy: 0.7966 - val_loss: 2.6507 - val_accuracy: 0.8873
# Epoch 8/100
# 125/125 [==============================] - 107s 860ms/step - loss: 3.0494 - accuracy: 0.8107 - val_loss: 2.8315 - val_accuracy: 0.8961
# Epoch 9/100
# 125/125 [==============================] - 104s 833ms/step - loss: 3.1668 - accuracy: 0.8102 - val_loss: 3.1717 - val_accuracy: 0.8878
# Epoch 10/100
# 125/125 [==============================] - 110s 882ms/step - loss: 3.1277 - accuracy: 0.8251 - val_loss: 2.8556 - val_accuracy: 0.9119
# Epoch 11/100
# 125/125 [==============================] - 108s 863ms/step - loss: 3.1670 - accuracy: 0.8125 - val_loss: 3.2134 - val_accuracy: 0.9008
# Epoch 12/100
# 125/125 [==============================] - 113s 906ms/step - loss: 3.2968 - accuracy: 0.8080 - val_loss: 3.0411 - val_accuracy: 0.8902
# Epoch 13/100
# 125/125 [==============================] - 110s 881ms/step - loss: 3.2140 - accuracy: 0.8168 - val_loss: 2.9815 - val_accuracy: 0.8937
# Epoch 14/100
# 125/125 [==============================] - 105s 839ms/step - loss: 3.1547 - accuracy: 0.8243 - val_loss: 3.2187 - val_accuracy: 0.9160
# Epoch 15/100
# 125/125 [==============================] - 108s 867ms/step - loss: 3.0241 - accuracy: 0.8379 - val_loss: 2.9969 - val_accuracy: 0.9084
# Epoch 16/100
# 125/125 [==============================] - 106s 850ms/step - loss: 3.0715 - accuracy: 0.8382 - val_loss: 2.9168 - val_accuracy: 0.9031
# Epoch 17/100
# 125/125 [==============================] - 108s 863ms/step - loss: 2.9508 - accuracy: 0.8427 - val_loss: 2.6830 - val_accuracy: 0.9090
# Epoch 18/100
# 125/125 [==============================] - 106s 850ms/step - loss: 2.8242 - accuracy: 0.8510 - val_loss: 2.8632 - val_accuracy: 0.9166
# Epoch 19/100
# 125/125 [==============================] - 109s 873ms/step - loss: 2.7479 - accuracy: 0.8543 - val_loss: 2.6036 - val_accuracy: 0.9196
# Epoch 20/100
# 125/125 [==============================] - 111s 888ms/step - loss: 2.5298 - accuracy: 0.8646 - val_loss: 2.6677 - val_accuracy: 0.9254
# Epoch 21/100
# 125/125 [==============================] - 107s 855ms/step - loss: 2.6230 - accuracy: 0.8686 - val_loss: 2.4854 - val_accuracy: 0.9154
# Epoch 22/100
# 125/125 [==============================] - 107s 859ms/step - loss: 2.5327 - accuracy: 0.8636 - val_loss: 2.7035 - val_accuracy: 0.9143
# Epoch 23/100
# 125/125 [==============================] - 109s 870ms/step - loss: 2.4591 - accuracy: 0.8739 - val_loss: 2.1854 - val_accuracy: 0.9278
# Epoch 24/100
# 125/125 [==============================] - 108s 865ms/step - loss: 2.2101 - accuracy: 0.8900 - val_loss: 2.4386 - val_accuracy: 0.9284
# Epoch 25/100
# 125/125 [==============================] - 110s 882ms/step - loss: 2.1361 - accuracy: 0.8928 - val_loss: 2.1800 - val_accuracy: 0.9248
# Epoch 26/100
# 125/125 [==============================] - 108s 864ms/step - loss: 2.1590 - accuracy: 0.8862 - val_loss: 2.1242 - val_accuracy: 0.9207
# Epoch 27/100
# 125/125 [==============================] - 106s 845ms/step - loss: 2.1432 - accuracy: 0.8930 - val_loss: 2.1015 - val_accuracy: 0.9260
# Epoch 28/100
# 125/125 [==============================] - 109s 870ms/step - loss: 1.9981 - accuracy: 0.9031 - val_loss: 2.0675 - val_accuracy: 0.9284
# Epoch 29/100
# 125/125 [==============================] - 108s 860ms/step - loss: 1.8792 - accuracy: 0.9066 - val_loss: 1.9515 - val_accuracy: 0.9272
# Epoch 30/100
# 125/125 [==============================] - 112s 898ms/step - loss: 1.8701 - accuracy: 0.9081 - val_loss: 1.8682 - val_accuracy: 0.9336
# Epoch 31/100
# 125/125 [==============================] - 122s 973ms/step - loss: 1.8878 - accuracy: 0.9049 - val_loss: 2.0993 - val_accuracy: 0.9331
# Epoch 32/100
# 125/125 [==============================] - 110s 877ms/step - loss: 1.8765 - accuracy: 0.9069 - val_loss: 1.9651 - val_accuracy: 0.9272
# Epoch 33/100
# 125/125 [==============================] - 108s 865ms/step - loss: 1.8236 - accuracy: 0.9028 - val_loss: 2.0090 - val_accuracy: 0.9372
# Epoch 34/100
# 125/125 [==============================] - 106s 849ms/step - loss: 1.8544 - accuracy: 0.9023 - val_loss: 1.9142 - val_accuracy: 0.9301
# Epoch 35/100
# 125/125 [==============================] - 109s 871ms/step - loss: 1.8036 - accuracy: 0.9051 - val_loss: 1.7692 - val_accuracy: 0.9342
# Epoch 36/100
# 125/125 [==============================] - 105s 836ms/step - loss: 1.8167 - accuracy: 0.9076 - val_loss: 1.8557 - val_accuracy: 0.9407
# Epoch 37/100
# 125/125 [==============================] - 109s 873ms/step - loss: 1.7547 - accuracy: 0.9184 - val_loss: 1.7600 - val_accuracy: 0.9342
# Epoch 38/100
# 125/125 [==============================] - 106s 846ms/step - loss: 1.6564 - accuracy: 0.9139 - val_loss: 1.7604 - val_accuracy: 0.9278
# Epoch 39/100
# 125/125 [==============================] - 108s 865ms/step - loss: 1.6373 - accuracy: 0.9119 - val_loss: 1.7503 - val_accuracy: 0.9301
# Epoch 40/100
# 125/125 [==============================] - 108s 864ms/step - loss: 1.6661 - accuracy: 0.9260 - val_loss: 1.5617 - val_accuracy: 0.9430
# Epoch 41/100
# 125/125 [==============================] - 111s 890ms/step - loss: 1.6015 - accuracy: 0.9222 - val_loss: 1.5639 - val_accuracy: 0.9342
# Epoch 42/100
# 125/125 [==============================] - 109s 869ms/step - loss: 1.5963 - accuracy: 0.9152 - val_loss: 1.6676 - val_accuracy: 0.9360
# Epoch 43/100
# 125/125 [==============================] - 107s 853ms/step - loss: 1.5286 - accuracy: 0.9247 - val_loss: 1.5408 - val_accuracy: 0.9366
# Epoch 44/100
# 125/125 [==============================] - 116s 929ms/step - loss: 1.5545 - accuracy: 0.9215 - val_loss: 1.6758 - val_accuracy: 0.9425
# Epoch 45/100
# 125/125 [==============================] - 112s 893ms/step - loss: 1.5890 - accuracy: 0.9200 - val_loss: 1.6317 - val_accuracy: 0.9454
# Epoch 46/100
# 125/125 [==============================] - 110s 881ms/step - loss: 1.5348 - accuracy: 0.9263 - val_loss: 1.6493 - val_accuracy: 0.9319
# Epoch 47/100
# 125/125 [==============================] - 112s 900ms/step - loss: 1.5993 - accuracy: 0.9149 - val_loss: 1.6400 - val_accuracy: 0.9389
# Epoch 48/100
# 125/125 [==============================] - 107s 859ms/step - loss: 1.5149 - accuracy: 0.9232 - val_loss: 1.4128 - val_accuracy: 0.9407
# Epoch 49/100
# 125/125 [==============================] - 109s 875ms/step - loss: 1.4219 - accuracy: 0.9252 - val_loss: 1.4917 - val_accuracy: 0.9348
# Epoch 50/100
# 125/125 [==============================] - 110s 878ms/step - loss: 1.3745 - accuracy: 0.9263 - val_loss: 1.4342 - val_accuracy: 0.9360
# Epoch 51/100
# 125/125 [==============================] - 108s 867ms/step - loss: 1.5690 - accuracy: 0.9152 - val_loss: 1.5389 - val_accuracy: 0.9272
# Epoch 52/100
# 125/125 [==============================] - 108s 861ms/step - loss: 1.3924 - accuracy: 0.9323 - val_loss: 1.4494 - val_accuracy: 0.9360
# Epoch 53/100
# 125/125 [==============================] - 110s 882ms/step - loss: 1.3769 - accuracy: 0.9235 - val_loss: 1.4162 - val_accuracy: 0.9354
# Epoch 54/100
# 125/125 [==============================] - 109s 871ms/step - loss: 1.4276 - accuracy: 0.9227 - val_loss: 1.5128 - val_accuracy: 0.9360
# Epoch 55/100
# 125/125 [==============================] - 110s 881ms/step - loss: 1.4200 - accuracy: 0.9288 - val_loss: 1.4836 - val_accuracy: 0.9331
# Epoch 56/100
# 125/125 [==============================] - 111s 885ms/step - loss: 1.3515 - accuracy: 0.9333 - val_loss: 1.4105 - val_accuracy: 0.9425
# Epoch 57/100
# 125/125 [==============================] - 108s 867ms/step - loss: 1.4225 - accuracy: 0.9333 - val_loss: 1.4442 - val_accuracy: 0.9295
# Epoch 58/100
# 125/125 [==============================] - 108s 863ms/step - loss: 1.3615 - accuracy: 0.9260 - val_loss: 1.4098 - val_accuracy: 0.9319
# Epoch 59/100
# 125/125 [==============================] - 111s 886ms/step - loss: 1.2951 - accuracy: 0.9333 - val_loss: 1.3888 - val_accuracy: 0.9348
# Epoch 60/100
# 125/125 [==============================] - 109s 876ms/step - loss: 1.3529 - accuracy: 0.9305 - val_loss: 1.3653 - val_accuracy: 0.9383
# Epoch 61/100
# 125/125 [==============================] - 108s 862ms/step - loss: 1.3967 - accuracy: 0.9273 - val_loss: 1.4055 - val_accuracy: 0.9477
# Epoch 62/100
# 125/125 [==============================] - 108s 862ms/step - loss: 1.2881 - accuracy: 0.9338 - val_loss: 1.2927 - val_accuracy: 0.9436
# Epoch 63/100
# 125/125 [==============================] - 108s 862ms/step - loss: 1.2116 - accuracy: 0.9371 - val_loss: 1.2444 - val_accuracy: 0.9436
# Epoch 64/100
# 125/125 [==============================] - 109s 875ms/step - loss: 1.2807 - accuracy: 0.9273 - val_loss: 1.4065 - val_accuracy: 0.9366
# Epoch 65/100
# 125/125 [==============================] - 102s 814ms/step - loss: 1.2990 - accuracy: 0.9328 - val_loss: 1.2537 - val_accuracy: 0.9383
# Epoch 66/100
# 125/125 [==============================] - 109s 872ms/step - loss: 1.2438 - accuracy: 0.9341 - val_loss: 1.3298 - val_accuracy: 0.9360
# Epoch 67/100
# 125/125 [==============================] - 103s 823ms/step - loss: 1.3631 - accuracy: 0.9265 - val_loss: 1.4070 - val_accuracy: 0.9336
# Epoch 68/100
# 125/125 [==============================] - 107s 858ms/step - loss: 1.3379 - accuracy: 0.9303 - val_loss: 1.3390 - val_accuracy: 0.9336
# Epoch 69/100
# 125/125 [==============================] - 106s 850ms/step - loss: 1.2497 - accuracy: 0.9391 - val_loss: 1.3526 - val_accuracy: 0.9336
# Epoch 70/100
# 125/125 [==============================] - 104s 830ms/step - loss: 1.2424 - accuracy: 0.9378 - val_loss: 1.1994 - val_accuracy: 0.9395
# Epoch 71/100
# 125/125 [==============================] - 109s 873ms/step - loss: 1.1894 - accuracy: 0.9336 - val_loss: 1.2703 - val_accuracy: 0.9425
# Epoch 72/100
# 125/125 [==============================] - 105s 842ms/step - loss: 1.2504 - accuracy: 0.9368 - val_loss: 1.2983 - val_accuracy: 0.9360
# Epoch 73/100
# 125/125 [==============================] - 106s 849ms/step - loss: 1.1968 - accuracy: 0.9388 - val_loss: 1.1916 - val_accuracy: 0.9454
# Epoch 74/100
# 125/125 [==============================] - 104s 832ms/step - loss: 1.1845 - accuracy: 0.9353 - val_loss: 1.3434 - val_accuracy: 0.9419
# Epoch 75/100
# 125/125 [==============================] - 107s 859ms/step - loss: 1.1994 - accuracy: 0.9290 - val_loss: 1.2307 - val_accuracy: 0.9407
# Epoch 76/100
# 125/125 [==============================] - 106s 850ms/step - loss: 1.2107 - accuracy: 0.9353 - val_loss: 1.2250 - val_accuracy: 0.9383
# Epoch 77/100
# 125/125 [==============================] - 105s 841ms/step - loss: 1.2243 - accuracy: 0.9303 - val_loss: 1.2198 - val_accuracy: 0.9395
# Epoch 78/100
# 125/125 [==============================] - 104s 835ms/step - loss: 1.1852 - accuracy: 0.9403 - val_loss: 1.2223 - val_accuracy: 0.9378
# Epoch 79/100
# 125/125 [==============================] - 110s 882ms/step - loss: 1.1516 - accuracy: 0.9373 - val_loss: 1.2288 - val_accuracy: 0.9413
# Epoch 80/100
# 125/125 [==============================] - 102s 818ms/step - loss: 1.2002 - accuracy: 0.9328 - val_loss: 1.1936 - val_accuracy: 0.9372
# Epoch 81/100
# 125/125 [==============================] - 107s 854ms/step - loss: 1.1861 - accuracy: 0.9358 - val_loss: 1.2255 - val_accuracy: 0.9395
# Epoch 82/100
# 125/125 [==============================] - 106s 847ms/step - loss: 1.1765 - accuracy: 0.9356 - val_loss: 1.2267 - val_accuracy: 0.9354
# Epoch 83/100
# 125/125 [==============================] - 106s 845ms/step - loss: 1.1503 - accuracy: 0.9368 - val_loss: 1.1752 - val_accuracy: 0.9448
# Epoch 84/100
# 125/125 [==============================] - 108s 865ms/step - loss: 1.1080 - accuracy: 0.9396 - val_loss: 1.0875 - val_accuracy: 0.9442
# Epoch 85/100
# 125/125 [==============================] - 101s 808ms/step - loss: 1.0960 - accuracy: 0.9343 - val_loss: 1.2203 - val_accuracy: 0.9419
# Epoch 86/100
# 125/125 [==============================] - 105s 841ms/step - loss: 1.1567 - accuracy: 0.9318 - val_loss: 1.1689 - val_accuracy: 0.9425
# Epoch 87/100
# 125/125 [==============================] - 112s 899ms/step - loss: 1.0778 - accuracy: 0.9368 - val_loss: 1.0760 - val_accuracy: 0.9419
# Epoch 88/100
# 125/125 [==============================] - 104s 836ms/step - loss: 1.0939 - accuracy: 0.9381 - val_loss: 1.1694 - val_accuracy: 0.9372
# Epoch 89/100
# 125/125 [==============================] - 103s 826ms/step - loss: 1.1233 - accuracy: 0.9421 - val_loss: 1.0670 - val_accuracy: 0.9442
# Epoch 90/100
# 125/125 [==============================] - 107s 855ms/step - loss: 1.0721 - accuracy: 0.9406 - val_loss: 1.1306 - val_accuracy: 0.9454
# Epoch 91/100
# 125/125 [==============================] - 104s 829ms/step - loss: 1.1065 - accuracy: 0.9391 - val_loss: 1.1302 - val_accuracy: 0.9413
# Epoch 92/100
# 125/125 [==============================] - 106s 851ms/step - loss: 1.0293 - accuracy: 0.9368 - val_loss: 1.1557 - val_accuracy: 0.9295
# Epoch 93/100
# 125/125 [==============================] - 102s 816ms/step - loss: 1.1215 - accuracy: 0.9376 - val_loss: 1.2292 - val_accuracy: 0.9354
# Epoch 94/100
# 125/125 [==============================] - 107s 856ms/step - loss: 1.1440 - accuracy: 0.9396 - val_loss: 1.1191 - val_accuracy: 0.9407
# Epoch 95/100
# 125/125 [==============================] - 107s 854ms/step - loss: 1.0740 - accuracy: 0.9383 - val_loss: 1.0804 - val_accuracy: 0.9413
# Epoch 96/100
# 125/125 [==============================] - 106s 851ms/step - loss: 1.0816 - accuracy: 0.9393 - val_loss: 1.1849 - val_accuracy: 0.9419
# Epoch 97/100
# 125/125 [==============================] - 104s 835ms/step - loss: 1.1301 - accuracy: 0.9386 - val_loss: 1.1517 - val_accuracy: 0.9430
# Epoch 98/100
# 125/125 [==============================] - 102s 820ms/step - loss: 1.0176 - accuracy: 0.9464 - val_loss: 1.0476 - val_accuracy: 0.9378
# Epoch 99/100
# 125/125 [==============================] - 107s 855ms/step - loss: 1.0457 - accuracy: 0.9333 - val_loss: 1.0732 - val_accuracy: 0.9448
# Epoch 100/100
# 125/125 [==============================] - 104s 831ms/step - loss: 1.0299 - accuracy: 0.9441 - val_loss: 1.0440 - val_accuracy: 0.9430
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 37561, 30)         180
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 37561, 30)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 1126830)           0
# _________________________________________________________________
# dense (Dense)                (None, 30)                33804930
# _________________________________________________________________
# dropout (Dropout)            (None, 30)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 186
# =================================================================
# Total params: 33,805,296
# Trainable params: 33,805,296
# Non-trainable params: 0
# _________________________________________________________________
# 54/54 [==============================] - 11s 195ms/step - loss: 1.0440 - accuracy: 0.9430
# prob 0
# processing
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_1 (Conv1D)            (None, 37561, 30)         180
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 37561, 30)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1126830)           0
# _________________________________________________________________
# dense_2 (Dense)              (None, 30)                33804930
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 30)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 6)                 186
# =================================================================
# Total params: 33,805,296
# Trainable params: 33,805,296
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 125/125 [==============================] - 104s 830ms/step - loss: 1.9349 - accuracy: 0.5459 - val_loss: 1.9705 - val_accuracy: 0.8403
# Epoch 2/100
# 125/125 [==============================] - 107s 852ms/step - loss: 2.1361 - accuracy: 0.7206 - val_loss: 2.1908 - val_accuracy: 0.8873
# Epoch 3/100
# 125/125 [==============================] - 106s 845ms/step - loss: 2.3442 - accuracy: 0.7682 - val_loss: 2.3561 - val_accuracy: 0.8732
# Epoch 4/100
# 125/125 [==============================] - 102s 820ms/step - loss: 2.5435 - accuracy: 0.7901 - val_loss: 2.4594 - val_accuracy: 0.8873
# Epoch 5/100
# 125/125 [==============================] - 107s 854ms/step - loss: 2.6148 - accuracy: 0.7956 - val_loss: 2.4920 - val_accuracy: 0.9002
# Epoch 6/100
# 125/125 [==============================] - 104s 832ms/step - loss: 2.7490 - accuracy: 0.8004 - val_loss: 2.6253 - val_accuracy: 0.8849
# Epoch 7/100
# 125/125 [==============================] - 99s 794ms/step - loss: 2.8433 - accuracy: 0.8027 - val_loss: 2.5838 - val_accuracy: 0.9031
# Epoch 8/100
# 125/125 [==============================] - 101s 812ms/step - loss: 2.8473 - accuracy: 0.8054 - val_loss: 2.7842 - val_accuracy: 0.8937
# Epoch 9/100
# 125/125 [==============================] - 105s 838ms/step - loss: 2.9997 - accuracy: 0.8069 - val_loss: 2.8927 - val_accuracy: 0.9037
# Epoch 10/100
# 125/125 [==============================] - 103s 821ms/step - loss: 3.0586 - accuracy: 0.8037 - val_loss: 3.0049 - val_accuracy: 0.8925
# Epoch 11/100
# 125/125 [==============================] - 102s 817ms/step - loss: 2.9493 - accuracy: 0.8231 - val_loss: 2.8331 - val_accuracy: 0.9014
# Epoch 12/100
# 125/125 [==============================] - 105s 843ms/step - loss: 3.0471 - accuracy: 0.8203 - val_loss: 2.7441 - val_accuracy: 0.8996
# Epoch 13/100
# 125/125 [==============================] - 104s 830ms/step - loss: 3.0664 - accuracy: 0.8127 - val_loss: 2.8296 - val_accuracy: 0.8902
# Epoch 14/100
# 125/125 [==============================] - 103s 821ms/step - loss: 3.0295 - accuracy: 0.8261 - val_loss: 3.0042 - val_accuracy: 0.9037
# Epoch 15/100
# 125/125 [==============================] - 105s 840ms/step - loss: 3.0642 - accuracy: 0.8273 - val_loss: 3.0874 - val_accuracy: 0.9137
# Epoch 16/100
# 125/125 [==============================] - 102s 820ms/step - loss: 3.0885 - accuracy: 0.8248 - val_loss: 2.8137 - val_accuracy: 0.8972
# Epoch 17/100
# 125/125 [==============================] - 99s 790ms/step - loss: 2.9743 - accuracy: 0.8293 - val_loss: 2.7311 - val_accuracy: 0.9107
# Epoch 18/100
# 125/125 [==============================] - 101s 807ms/step - loss: 2.9529 - accuracy: 0.8304 - val_loss: 2.8597 - val_accuracy: 0.9107
# Epoch 19/100
# 125/125 [==============================] - 103s 820ms/step - loss: 2.7174 - accuracy: 0.8538 - val_loss: 2.7694 - val_accuracy: 0.8925
# Epoch 20/100
# 125/125 [==============================] - 102s 819ms/step - loss: 2.7992 - accuracy: 0.8548 - val_loss: 2.7780 - val_accuracy: 0.9160
# Epoch 21/100
# 125/125 [==============================] - 103s 822ms/step - loss: 2.6059 - accuracy: 0.8601 - val_loss: 2.6705 - val_accuracy: 0.9190
# Epoch 22/100
# 125/125 [==============================] - 109s 876ms/step - loss: 2.6460 - accuracy: 0.8555 - val_loss: 2.5517 - val_accuracy: 0.9178
# Epoch 23/100
# 125/125 [==============================] - 100s 803ms/step - loss: 2.5991 - accuracy: 0.8656 - val_loss: 2.4745 - val_accuracy: 0.9225
# Epoch 24/100
# 125/125 [==============================] - 111s 887ms/step - loss: 2.4003 - accuracy: 0.8747 - val_loss: 2.2970 - val_accuracy: 0.9325
# Epoch 25/100
# 125/125 [==============================] - 103s 824ms/step - loss: 2.2502 - accuracy: 0.8830 - val_loss: 2.3346 - val_accuracy: 0.9201
# Epoch 26/100
# 125/125 [==============================] - 107s 855ms/step - loss: 2.2449 - accuracy: 0.8799 - val_loss: 2.3693 - val_accuracy: 0.9243
# Epoch 27/100
# 125/125 [==============================] - 105s 841ms/step - loss: 2.1786 - accuracy: 0.8812 - val_loss: 2.1562 - val_accuracy: 0.9307
# Epoch 28/100
# 125/125 [==============================] - 104s 831ms/step - loss: 2.1205 - accuracy: 0.8880 - val_loss: 2.0376 - val_accuracy: 0.9284
# Epoch 29/100
# 125/125 [==============================] - 103s 825ms/step - loss: 2.1156 - accuracy: 0.8837 - val_loss: 2.1785 - val_accuracy: 0.9307
# Epoch 30/100
# 125/125 [==============================] - 106s 848ms/step - loss: 2.0000 - accuracy: 0.8968 - val_loss: 1.9848 - val_accuracy: 0.9301
# Epoch 31/100
# 125/125 [==============================] - 109s 872ms/step - loss: 1.9452 - accuracy: 0.8938 - val_loss: 1.9475 - val_accuracy: 0.9266
# Epoch 32/100
# 125/125 [==============================] - 107s 856ms/step - loss: 1.9312 - accuracy: 0.8968 - val_loss: 2.0517 - val_accuracy: 0.9383
# Epoch 33/100
# 125/125 [==============================] - 106s 848ms/step - loss: 1.9640 - accuracy: 0.9069 - val_loss: 1.9785 - val_accuracy: 0.9289
# Epoch 34/100
# 125/125 [==============================] - 105s 842ms/step - loss: 1.7864 - accuracy: 0.9101 - val_loss: 1.8359 - val_accuracy: 0.9372
# Epoch 35/100
# 125/125 [==============================] - 102s 819ms/step - loss: 1.8020 - accuracy: 0.9039 - val_loss: 1.9641 - val_accuracy: 0.9325
# Epoch 36/100
# 125/125 [==============================] - 107s 859ms/step - loss: 1.7958 - accuracy: 0.9046 - val_loss: 1.9099 - val_accuracy: 0.9319
# Epoch 37/100
# 125/125 [==============================] - 102s 815ms/step - loss: 1.8339 - accuracy: 0.9064 - val_loss: 1.8052 - val_accuracy: 0.9460
# Epoch 38/100
# 125/125 [==============================] - 111s 890ms/step - loss: 1.7955 - accuracy: 0.9086 - val_loss: 1.9148 - val_accuracy: 0.9266
# Epoch 39/100
# 125/125 [==============================] - 106s 845ms/step - loss: 1.8264 - accuracy: 0.9066 - val_loss: 1.8531 - val_accuracy: 0.9360
# Epoch 40/100
# 125/125 [==============================] - 102s 814ms/step - loss: 1.7949 - accuracy: 0.9122 - val_loss: 1.7886 - val_accuracy: 0.9378
# Epoch 41/100
# 125/125 [==============================] - 106s 849ms/step - loss: 1.7006 - accuracy: 0.9159 - val_loss: 1.7691 - val_accuracy: 0.9419
# Epoch 42/100
# 125/125 [==============================] - 105s 840ms/step - loss: 1.6445 - accuracy: 0.9220 - val_loss: 1.6612 - val_accuracy: 0.9401
# Epoch 43/100
# 125/125 [==============================] - 103s 820ms/step - loss: 1.6908 - accuracy: 0.9179 - val_loss: 1.7106 - val_accuracy: 0.9342
# Epoch 44/100
# 125/125 [==============================] - 107s 854ms/step - loss: 1.6424 - accuracy: 0.9129 - val_loss: 1.7236 - val_accuracy: 0.9372
# Epoch 45/100
# 125/125 [==============================] - 106s 850ms/step - loss: 1.7408 - accuracy: 0.9137 - val_loss: 1.7340 - val_accuracy: 0.9331
# Epoch 46/100
# 125/125 [==============================] - 104s 836ms/step - loss: 1.6025 - accuracy: 0.9192 - val_loss: 1.7035 - val_accuracy: 0.9325
# Epoch 47/100
# 125/125 [==============================] - 102s 817ms/step - loss: 1.6728 - accuracy: 0.9089 - val_loss: 1.7983 - val_accuracy: 0.9325
# Epoch 48/100
# 125/125 [==============================] - 104s 836ms/step - loss: 1.7030 - accuracy: 0.9177 - val_loss: 1.8576 - val_accuracy: 0.9389
# Epoch 49/100
# 125/125 [==============================] - 107s 855ms/step - loss: 1.6099 - accuracy: 0.9237 - val_loss: 1.6438 - val_accuracy: 0.9336
# Epoch 50/100
# 125/125 [==============================] - 103s 825ms/step - loss: 1.6312 - accuracy: 0.9162 - val_loss: 1.6935 - val_accuracy: 0.9348
# Epoch 51/100
# 125/125 [==============================] - 103s 827ms/step - loss: 1.6496 - accuracy: 0.9179 - val_loss: 1.5838 - val_accuracy: 0.9354
# Epoch 52/100
# 125/125 [==============================] - 106s 848ms/step - loss: 1.5144 - accuracy: 0.9230 - val_loss: 1.5678 - val_accuracy: 0.9407
# Epoch 53/100
# 125/125 [==============================] - 103s 825ms/step - loss: 1.5442 - accuracy: 0.9177 - val_loss: 1.5994 - val_accuracy: 0.9395
# Epoch 54/100
# 125/125 [==============================] - 103s 820ms/step - loss: 1.6002 - accuracy: 0.9192 - val_loss: 1.6153 - val_accuracy: 0.9419
# Epoch 55/100
# 125/125 [==============================] - 103s 827ms/step - loss: 1.4926 - accuracy: 0.9260 - val_loss: 1.4990 - val_accuracy: 0.9460
# Epoch 56/100
# 125/125 [==============================] - 105s 841ms/step - loss: 1.5436 - accuracy: 0.9169 - val_loss: 1.5675 - val_accuracy: 0.9378
# Epoch 57/100
# 125/125 [==============================] - 106s 850ms/step - loss: 1.5747 - accuracy: 0.9142 - val_loss: 1.6921 - val_accuracy: 0.9354
# Epoch 58/100
# 125/125 [==============================] - 101s 810ms/step - loss: 1.7426 - accuracy: 0.9184 - val_loss: 1.5812 - val_accuracy: 0.9319
# Epoch 59/100
# 125/125 [==============================] - 103s 822ms/step - loss: 1.5298 - accuracy: 0.9220 - val_loss: 1.5589 - val_accuracy: 0.9319
# Epoch 60/100
# 125/125 [==============================] - 104s 829ms/step - loss: 1.4812 - accuracy: 0.9225 - val_loss: 1.5455 - val_accuracy: 0.9307
# Epoch 61/100
# 125/125 [==============================] - 98s 784ms/step - loss: 1.4545 - accuracy: 0.9283 - val_loss: 1.4805 - val_accuracy: 0.9383
# Epoch 62/100
# 125/125 [==============================] - 101s 811ms/step - loss: 1.4521 - accuracy: 0.9235 - val_loss: 1.4619 - val_accuracy: 0.9448
# Epoch 63/100
# 125/125 [==============================] - 100s 798ms/step - loss: 1.4419 - accuracy: 0.9320 - val_loss: 1.5932 - val_accuracy: 0.9389
# Epoch 64/100
# 125/125 [==============================] - 99s 796ms/step - loss: 1.4818 - accuracy: 0.9270 - val_loss: 1.5058 - val_accuracy: 0.9383
# Epoch 65/100
# 125/125 [==============================] - 103s 823ms/step - loss: 1.4848 - accuracy: 0.9195 - val_loss: 1.5057 - val_accuracy: 0.9407
# Epoch 66/100
# 125/125 [==============================] - 100s 800ms/step - loss: 1.4571 - accuracy: 0.9268 - val_loss: 1.4097 - val_accuracy: 0.9460
# Epoch 67/100
# 125/125 [==============================] - 98s 783ms/step - loss: 1.3977 - accuracy: 0.9343 - val_loss: 1.3927 - val_accuracy: 0.9307
# Epoch 68/100
# 125/125 [==============================] - 101s 804ms/step - loss: 1.3985 - accuracy: 0.9290 - val_loss: 1.4232 - val_accuracy: 0.9366
# Epoch 69/100
# 125/125 [==============================] - 101s 808ms/step - loss: 1.4090 - accuracy: 0.9295 - val_loss: 1.5361 - val_accuracy: 0.9383
# Epoch 70/100
# 125/125 [==============================] - 97s 774ms/step - loss: 1.3857 - accuracy: 0.9325 - val_loss: 1.4019 - val_accuracy: 0.9466
# Epoch 71/100
# 125/125 [==============================] - 102s 813ms/step - loss: 1.3357 - accuracy: 0.9293 - val_loss: 1.4188 - val_accuracy: 0.9413
# Epoch 72/100
# 125/125 [==============================] - 103s 820ms/step - loss: 1.3712 - accuracy: 0.9250 - val_loss: 1.4205 - val_accuracy: 0.9336
# Epoch 73/100
# 125/125 [==============================] - 103s 824ms/step - loss: 1.3557 - accuracy: 0.9328 - val_loss: 1.4296 - val_accuracy: 0.9401
# Epoch 74/100
# 125/125 [==============================] - 106s 845ms/step - loss: 1.4031 - accuracy: 0.9288 - val_loss: 1.3477 - val_accuracy: 0.9395
# Epoch 75/100
# 125/125 [==============================] - 105s 841ms/step - loss: 1.2955 - accuracy: 0.9341 - val_loss: 1.3509 - val_accuracy: 0.9448
# Epoch 76/100
# 125/125 [==============================] - 109s 876ms/step - loss: 1.2906 - accuracy: 0.9295 - val_loss: 1.2551 - val_accuracy: 0.9425
# Epoch 77/100
# 125/125 [==============================] - 102s 818ms/step - loss: 1.2278 - accuracy: 0.9320 - val_loss: 1.3103 - val_accuracy: 0.9489
# Epoch 78/100
# 125/125 [==============================] - 111s 887ms/step - loss: 1.2665 - accuracy: 0.9348 - val_loss: 1.3204 - val_accuracy: 0.9413
# Epoch 79/100
# 125/125 [==============================] - 99s 795ms/step - loss: 1.2933 - accuracy: 0.9268 - val_loss: 1.2959 - val_accuracy: 0.9460
# Epoch 80/100
# 125/125 [==============================] - 107s 859ms/step - loss: 1.2497 - accuracy: 0.9330 - val_loss: 1.1890 - val_accuracy: 0.9425
# Epoch 81/100
# 125/125 [==============================] - 107s 854ms/step - loss: 1.1659 - accuracy: 0.9371 - val_loss: 1.2710 - val_accuracy: 0.9366
# Epoch 82/100
# 125/125 [==============================] - 103s 824ms/step - loss: 1.2431 - accuracy: 0.9325 - val_loss: 1.2247 - val_accuracy: 0.9419
# Epoch 83/100
# 125/125 [==============================] - 105s 841ms/step - loss: 1.1912 - accuracy: 0.9351 - val_loss: 1.2451 - val_accuracy: 0.9419
# Epoch 84/100
# 125/125 [==============================] - 104s 832ms/step - loss: 1.1177 - accuracy: 0.9451 - val_loss: 1.1174 - val_accuracy: 0.9448
# Epoch 85/100
# 125/125 [==============================] - 103s 824ms/step - loss: 1.1377 - accuracy: 0.9376 - val_loss: 1.2268 - val_accuracy: 0.9454
# Epoch 86/100
# 125/125 [==============================] - 102s 818ms/step - loss: 1.1172 - accuracy: 0.9386 - val_loss: 1.1108 - val_accuracy: 0.9501
# Epoch 87/100
# 125/125 [==============================] - 106s 850ms/step - loss: 1.0981 - accuracy: 0.9406 - val_loss: 1.1908 - val_accuracy: 0.9489
# Epoch 88/100
# 125/125 [==============================] - 101s 809ms/step - loss: 1.1505 - accuracy: 0.9406 - val_loss: 1.2001 - val_accuracy: 0.9454
# Epoch 89/100
# 125/125 [==============================] - 103s 820ms/step - loss: 1.1162 - accuracy: 0.9431 - val_loss: 1.1533 - val_accuracy: 0.9378
# Epoch 90/100
# 125/125 [==============================] - 102s 820ms/step - loss: 1.1085 - accuracy: 0.9396 - val_loss: 1.1125 - val_accuracy: 0.9436
# Epoch 91/100
# 125/125 [==============================] - 101s 811ms/step - loss: 1.0864 - accuracy: 0.9434 - val_loss: 1.1318 - val_accuracy: 0.9472
# Epoch 92/100
# 125/125 [==============================] - 105s 839ms/step - loss: 1.0721 - accuracy: 0.9398 - val_loss: 1.1122 - val_accuracy: 0.9472
# Epoch 93/100
# 125/125 [==============================] - 103s 820ms/step - loss: 1.0505 - accuracy: 0.9449 - val_loss: 1.1248 - val_accuracy: 0.9483
# Epoch 94/100
# 125/125 [==============================] - 103s 821ms/step - loss: 1.0759 - accuracy: 0.9396 - val_loss: 1.1253 - val_accuracy: 0.9448
# Epoch 95/100
# 125/125 [==============================] - 100s 798ms/step - loss: 1.0008 - accuracy: 0.9429 - val_loss: 1.0465 - val_accuracy: 0.9477
# Epoch 96/100
# 125/125 [==============================] - 104s 829ms/step - loss: 1.0194 - accuracy: 0.9446 - val_loss: 1.0452 - val_accuracy: 0.9413
# Epoch 97/100
# 125/125 [==============================] - 105s 839ms/step - loss: 0.9390 - accuracy: 0.9466 - val_loss: 0.9952 - val_accuracy: 0.9442
# Epoch 98/100
# 125/125 [==============================] - 105s 841ms/step - loss: 1.0027 - accuracy: 0.9441 - val_loss: 1.0874 - val_accuracy: 0.9366
# Epoch 99/100
# 125/125 [==============================] - 102s 817ms/step - loss: 0.9722 - accuracy: 0.9464 - val_loss: 0.9895 - val_accuracy: 0.9489
# Epoch 100/100
# 125/125 [==============================] - 102s 820ms/step - loss: 0.9968 - accuracy: 0.9398 - val_loss: 1.0801 - val_accuracy: 0.9454
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_1 (Conv1D)            (None, 37561, 30)         180
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 37561, 30)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1126830)           0
# _________________________________________________________________
# dense_2 (Dense)              (None, 30)                33804930
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 30)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 6)                 186
# =================================================================
# Total params: 33,805,296
# Trainable params: 33,805,296
# Non-trainable params: 0
# _________________________________________________________________
# 54/54 [==============================] - 10s 193ms/step - loss: 1.0801 - accuracy: 0.9454
# prob 0
# processing
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_2 (Conv1D)            (None, 37561, 30)         180
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 37561, 30)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 1126830)           0
# _________________________________________________________________
# dense_4 (Dense)              (None, 30)                33804930
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 30)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 6)                 186
# =================================================================
# Total params: 33,805,296
# Trainable params: 33,805,296
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 125/125 [==============================] - 101s 807ms/step - loss: 1.9361 - accuracy: 0.5047 - val_loss: 1.9396 - val_accuracy: 0.8039
# Epoch 2/100
# 125/125 [==============================] - 102s 818ms/step - loss: 2.1336 - accuracy: 0.6952 - val_loss: 2.1689 - val_accuracy: 0.8626
# Epoch 3/100
# 125/125 [==============================] - 104s 828ms/step - loss: 2.3564 - accuracy: 0.7581 - val_loss: 2.3281 - val_accuracy: 0.8896
# Epoch 4/100
# 125/125 [==============================] - 99s 796ms/step - loss: 2.5548 - accuracy: 0.7785 - val_loss: 2.4802 - val_accuracy: 0.8949
# Epoch 5/100
# 125/125 [==============================] - 102s 814ms/step - loss: 2.7240 - accuracy: 0.7898 - val_loss: 2.5325 - val_accuracy: 0.8597
# Epoch 6/100
# 125/125 [==============================] - 96s 766ms/step - loss: 2.7910 - accuracy: 0.7923 - val_loss: 2.6607 - val_accuracy: 0.8949
# Epoch 7/100
# 125/125 [==============================] - 99s 796ms/step - loss: 2.9062 - accuracy: 0.7941 - val_loss: 2.8196 - val_accuracy: 0.8767
# Epoch 8/100
# 125/125 [==============================] - 98s 786ms/step - loss: 3.0216 - accuracy: 0.7984 - val_loss: 2.9916 - val_accuracy: 0.8978
# Epoch 9/100
# 125/125 [==============================] - 100s 799ms/step - loss: 3.0403 - accuracy: 0.7946 - val_loss: 2.6921 - val_accuracy: 0.8831
# Epoch 10/100
# 125/125 [==============================] - 98s 787ms/step - loss: 3.1321 - accuracy: 0.7981 - val_loss: 2.7931 - val_accuracy: 0.8902
# Epoch 11/100
# 125/125 [==============================] - 98s 785ms/step - loss: 3.0765 - accuracy: 0.8092 - val_loss: 3.0180 - val_accuracy: 0.9125
# Epoch 12/100
# 125/125 [==============================] - 102s 814ms/step - loss: 3.1317 - accuracy: 0.8160 - val_loss: 2.9817 - val_accuracy: 0.8908
# Epoch 13/100
# 125/125 [==============================] - 97s 772ms/step - loss: 3.1272 - accuracy: 0.8137 - val_loss: 3.0525 - val_accuracy: 0.8990
# Epoch 14/100
# 125/125 [==============================] - 98s 785ms/step - loss: 3.1986 - accuracy: 0.8039 - val_loss: 3.0175 - val_accuracy: 0.8978
# Epoch 15/100
# 125/125 [==============================] - 99s 795ms/step - loss: 3.0937 - accuracy: 0.8178 - val_loss: 2.9246 - val_accuracy: 0.9066
# Epoch 16/100
# 125/125 [==============================] - 100s 797ms/step - loss: 3.0621 - accuracy: 0.8256 - val_loss: 2.9319 - val_accuracy: 0.9002
# Epoch 17/100
# 125/125 [==============================] - 98s 786ms/step - loss: 2.9948 - accuracy: 0.8200 - val_loss: 2.7129 - val_accuracy: 0.9107
# Epoch 18/100
# 125/125 [==============================] - 101s 807ms/step - loss: 2.9661 - accuracy: 0.8359 - val_loss: 2.7050 - val_accuracy: 0.9125
# Epoch 19/100
# 125/125 [==============================] - 98s 783ms/step - loss: 2.7456 - accuracy: 0.8384 - val_loss: 2.4747 - val_accuracy: 0.9225
# Epoch 20/100
# 125/125 [==============================] - 101s 806ms/step - loss: 2.7046 - accuracy: 0.8470 - val_loss: 2.5851 - val_accuracy: 0.9043
# Epoch 21/100
# 125/125 [==============================] - 97s 778ms/step - loss: 2.7477 - accuracy: 0.8361 - val_loss: 2.6184 - val_accuracy: 0.9248
# Epoch 22/100
# 125/125 [==============================] - 98s 788ms/step - loss: 2.5870 - accuracy: 0.8495 - val_loss: 2.5015 - val_accuracy: 0.9131
# Epoch 23/100
# 125/125 [==============================] - 100s 802ms/step - loss: 2.4894 - accuracy: 0.8550 - val_loss: 2.4480 - val_accuracy: 0.9201
# Epoch 24/100
# 125/125 [==============================] - 99s 789ms/step - loss: 2.3283 - accuracy: 0.8689 - val_loss: 2.3593 - val_accuracy: 0.9307
# Epoch 25/100
# 125/125 [==============================] - 96s 770ms/step - loss: 2.3699 - accuracy: 0.8656 - val_loss: 2.3535 - val_accuracy: 0.9243
# Epoch 26/100
# 125/125 [==============================] - 97s 778ms/step - loss: 2.2234 - accuracy: 0.8779 - val_loss: 2.2545 - val_accuracy: 0.9196
# Epoch 27/100
# 125/125 [==============================] - 97s 776ms/step - loss: 2.0959 - accuracy: 0.8870 - val_loss: 2.1492 - val_accuracy: 0.9336
# Epoch 28/100
# 125/125 [==============================] - 101s 807ms/step - loss: 2.0610 - accuracy: 0.8872 - val_loss: 2.0170 - val_accuracy: 0.9348
# Epoch 29/100
# 125/125 [==============================] - 100s 799ms/step - loss: 1.8774 - accuracy: 0.8963 - val_loss: 1.8558 - val_accuracy: 0.9325
# Epoch 30/100
# 125/125 [==============================] - 96s 770ms/step - loss: 1.9562 - accuracy: 0.8971 - val_loss: 2.0996 - val_accuracy: 0.9313
# Epoch 31/100
# 125/125 [==============================] - 99s 790ms/step - loss: 1.9054 - accuracy: 0.8953 - val_loss: 1.9294 - val_accuracy: 0.9389
# Epoch 32/100
# 125/125 [==============================] - 97s 777ms/step - loss: 1.8916 - accuracy: 0.8983 - val_loss: 1.8427 - val_accuracy: 0.9342
# Epoch 33/100
# 125/125 [==============================] - 98s 785ms/step - loss: 1.8211 - accuracy: 0.8950 - val_loss: 1.8339 - val_accuracy: 0.9348
# Epoch 34/100
# 125/125 [==============================] - 100s 802ms/step - loss: 1.8696 - accuracy: 0.8948 - val_loss: 1.8775 - val_accuracy: 0.9295
# Epoch 35/100
# 125/125 [==============================] - 97s 778ms/step - loss: 1.8204 - accuracy: 0.8981 - val_loss: 1.7537 - val_accuracy: 0.9430
# Epoch 36/100
# 125/125 [==============================] - 100s 802ms/step - loss: 1.8414 - accuracy: 0.8958 - val_loss: 1.8167 - val_accuracy: 0.9383
# Epoch 37/100
# 125/125 [==============================] - 95s 760ms/step - loss: 1.8173 - accuracy: 0.8973 - val_loss: 1.7490 - val_accuracy: 0.9289
# Epoch 38/100
# 125/125 [==============================] - 100s 803ms/step - loss: 1.7481 - accuracy: 0.9039 - val_loss: 1.7999 - val_accuracy: 0.9395
# Epoch 39/100
# 125/125 [==============================] - 98s 784ms/step - loss: 1.7050 - accuracy: 0.9031 - val_loss: 1.7250 - val_accuracy: 0.9378
# Epoch 40/100
# 125/125 [==============================] - 96s 767ms/step - loss: 1.7202 - accuracy: 0.9056 - val_loss: 1.6131 - val_accuracy: 0.9442
# Epoch 41/100
# 125/125 [==============================] - 101s 811ms/step - loss: 1.6835 - accuracy: 0.9036 - val_loss: 1.7649 - val_accuracy: 0.9336
# Epoch 42/100
# 125/125 [==============================] - 94s 749ms/step - loss: 1.7096 - accuracy: 0.9069 - val_loss: 1.7007 - val_accuracy: 0.9366
# Epoch 43/100
# 125/125 [==============================] - 101s 805ms/step - loss: 1.7284 - accuracy: 0.9049 - val_loss: 1.6731 - val_accuracy: 0.9430
# Epoch 44/100
# 125/125 [==============================] - 97s 775ms/step - loss: 1.7041 - accuracy: 0.9044 - val_loss: 1.7622 - val_accuracy: 0.9401
# Epoch 45/100
# 125/125 [==============================] - 95s 764ms/step - loss: 1.7757 - accuracy: 0.9054 - val_loss: 1.7290 - val_accuracy: 0.9395
# Epoch 46/100
# 125/125 [==============================] - 100s 797ms/step - loss: 1.6490 - accuracy: 0.9049 - val_loss: 1.7529 - val_accuracy: 0.9313
# Epoch 47/100
# 125/125 [==============================] - 99s 792ms/step - loss: 1.6580 - accuracy: 0.9069 - val_loss: 1.5785 - val_accuracy: 0.9389
# Epoch 48/100
# 125/125 [==============================] - 98s 781ms/step - loss: 1.6206 - accuracy: 0.9079 - val_loss: 1.6969 - val_accuracy: 0.9254
# Epoch 49/100
# 125/125 [==============================] - 95s 762ms/step - loss: 1.5825 - accuracy: 0.9200 - val_loss: 1.5704 - val_accuracy: 0.9419
# Epoch 50/100
# 125/125 [==============================] - 102s 817ms/step - loss: 1.6368 - accuracy: 0.9066 - val_loss: 1.6623 - val_accuracy: 0.9378
# Epoch 51/100
# 125/125 [==============================] - 96s 769ms/step - loss: 1.5941 - accuracy: 0.9129 - val_loss: 1.6150 - val_accuracy: 0.9342
# Epoch 52/100
# 125/125 [==============================] - 99s 792ms/step - loss: 1.5529 - accuracy: 0.9074 - val_loss: 1.5787 - val_accuracy: 0.9425
# Epoch 53/100
# 125/125 [==============================] - 99s 795ms/step - loss: 1.5672 - accuracy: 0.9124 - val_loss: 1.5385 - val_accuracy: 0.9348
# Epoch 54/100
# 125/125 [==============================] - 98s 784ms/step - loss: 1.4737 - accuracy: 0.9205 - val_loss: 1.5096 - val_accuracy: 0.9477
# Epoch 55/100
# 125/125 [==============================] - 99s 792ms/step - loss: 1.5180 - accuracy: 0.9152 - val_loss: 1.5704 - val_accuracy: 0.9336
# Epoch 56/100
# 125/125 [==============================] - 97s 774ms/step - loss: 1.4727 - accuracy: 0.9192 - val_loss: 1.4425 - val_accuracy: 0.9366
# Epoch 57/100
# 125/125 [==============================] - 98s 785ms/step - loss: 1.4211 - accuracy: 0.9137 - val_loss: 1.4097 - val_accuracy: 0.9401
# Epoch 58/100
# 125/125 [==============================] - 95s 757ms/step - loss: 1.4660 - accuracy: 0.9172 - val_loss: 1.4506 - val_accuracy: 0.9419
# Epoch 59/100
# 125/125 [==============================] - 96s 766ms/step - loss: 1.3886 - accuracy: 0.9270 - val_loss: 1.3756 - val_accuracy: 0.9360
# Epoch 60/100
# 125/125 [==============================] - 99s 791ms/step - loss: 1.3536 - accuracy: 0.9278 - val_loss: 1.4087 - val_accuracy: 0.9389
# Epoch 61/100
# 125/125 [==============================] - 100s 799ms/step - loss: 1.3939 - accuracy: 0.9157 - val_loss: 1.3249 - val_accuracy: 0.9436
# Epoch 62/100
# 125/125 [==============================] - 95s 762ms/step - loss: 1.3816 - accuracy: 0.9179 - val_loss: 1.3933 - val_accuracy: 0.9425
# Epoch 63/100
# 125/125 [==============================] - 97s 773ms/step - loss: 1.3377 - accuracy: 0.9205 - val_loss: 1.3125 - val_accuracy: 0.9448
# Epoch 64/100
# 125/125 [==============================] - 96s 770ms/step - loss: 1.3168 - accuracy: 0.9237 - val_loss: 1.3590 - val_accuracy: 0.9336
# Epoch 65/100
# 125/125 [==============================] - 96s 765ms/step - loss: 1.2982 - accuracy: 0.9268 - val_loss: 1.3235 - val_accuracy: 0.9331
# Epoch 66/100
# 125/125 [==============================] - 100s 802ms/step - loss: 1.2268 - accuracy: 0.9278 - val_loss: 1.3565 - val_accuracy: 0.9442
# Epoch 67/100
# 125/125 [==============================] - 95s 763ms/step - loss: 1.3187 - accuracy: 0.9210 - val_loss: 1.2762 - val_accuracy: 0.9430
# Epoch 68/100
# 125/125 [==============================] - 99s 790ms/step - loss: 1.2767 - accuracy: 0.9250 - val_loss: 1.3297 - val_accuracy: 0.9466
# Epoch 69/100
# 125/125 [==============================] - 102s 814ms/step - loss: 1.1984 - accuracy: 0.9368 - val_loss: 1.1710 - val_accuracy: 0.9331
# Epoch 70/100
# 125/125 [==============================] - 95s 756ms/step - loss: 1.1831 - accuracy: 0.9285 - val_loss: 1.2677 - val_accuracy: 0.9489
# Epoch 71/100
# 125/125 [==============================] - 95s 760ms/step - loss: 1.2671 - accuracy: 0.9235 - val_loss: 1.2307 - val_accuracy: 0.9389
# Epoch 72/100
# 125/125 [==============================] - 97s 778ms/step - loss: 1.2650 - accuracy: 0.9210 - val_loss: 1.2639 - val_accuracy: 0.9395
# Epoch 73/100
# 125/125 [==============================] - 99s 796ms/step - loss: 1.1993 - accuracy: 0.9336 - val_loss: 1.2198 - val_accuracy: 0.9448
# Epoch 74/100
# 125/125 [==============================] - 98s 781ms/step - loss: 1.1421 - accuracy: 0.9293 - val_loss: 1.1833 - val_accuracy: 0.9372
# Epoch 75/100
# 125/125 [==============================] - 97s 778ms/step - loss: 1.1482 - accuracy: 0.9315 - val_loss: 1.2311 - val_accuracy: 0.9442
# Epoch 76/100
# 125/125 [==============================] - 97s 776ms/step - loss: 1.2091 - accuracy: 0.9303 - val_loss: 1.2623 - val_accuracy: 0.9413
# Epoch 77/100
# 125/125 [==============================] - 101s 807ms/step - loss: 1.1745 - accuracy: 0.9257 - val_loss: 1.2306 - val_accuracy: 0.9407
# Epoch 78/100
# 125/125 [==============================] - 95s 764ms/step - loss: 1.2054 - accuracy: 0.9257 - val_loss: 1.2487 - val_accuracy: 0.9389
# Epoch 79/100
# 125/125 [==============================] - 95s 762ms/step - loss: 1.1901 - accuracy: 0.9303 - val_loss: 1.1764 - val_accuracy: 0.9448
# Epoch 80/100
# 125/125 [==============================] - 99s 789ms/step - loss: 1.0642 - accuracy: 0.9414 - val_loss: 1.1149 - val_accuracy: 0.9348
# Epoch 81/100
# 125/125 [==============================] - 97s 780ms/step - loss: 1.0865 - accuracy: 0.9366 - val_loss: 1.1199 - val_accuracy: 0.9319
# Epoch 82/100
# 125/125 [==============================] - 97s 780ms/step - loss: 1.0440 - accuracy: 0.9391 - val_loss: 1.0876 - val_accuracy: 0.9460
# Epoch 83/100
# 125/125 [==============================] - 99s 789ms/step - loss: 1.0851 - accuracy: 0.9328 - val_loss: 1.0798 - val_accuracy: 0.9454
# Epoch 84/100
# ...
# |    1    | 0.9688540627799336 |
# |    2    | 0.9688913946916603 |
# |    3    | 0.9691117409472625 |
# |    4    | 0.9656365245086906 |
# |    5    | 0.9634932247517329 |
# | Average | 0.967197389535856  |
# +---------+--------------------+
# ###############
# ###############
# ###############
# prob 1703
# Dist Mat shape 1703
# Element shape 3973
# (1703, 6)
# C:\Users\hassa\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1201: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
# prob 1703
# Dist Mat shape 1703
# Element shape 3973
# (1703, 6)
# C:\Users\hassa\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1201: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
# prob 1703
# Dist Mat shape 1703
# Element shape 3973
# (1703, 6)
# C:\Users\hassa\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1201: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
# prob 1703
# Dist Mat shape 1703
# Element shape 3973
# (1703, 6)
# C:\Users\hassa\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1201: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
# prob 1703
# Dist Mat shape 1703
# Element shape 3973
# (1703, 6)
# C:\Users\hassa\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1201: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
# metric EDice
# time 0:30:53.081307
# measure Accuracy
# +---------+--------------------+
# |  split  |      DataSet1      |
# +---------+--------------------+
# |    1    | 0.9442160892542572 |
# |    2    | 0.9459776864357017 |
# |    3    | 0.9448032883147387 |
# |    4    | 0.9406928948913682 |
# |    5    | 0.9342337052260716 |
# | Average | 0.9419847328244273 |
# +---------+--------------------+
# metric EDice
# time 0:30:53.081307
# measure Macro Precision
# +---------+--------------------+
# |  split  |      DataSet1      |
# +---------+--------------------+
# |    1    | 0.9465760266140562 |
# |    2    | 0.9484584745113481 |
# |    3    | 0.9466539370379742 |
# |    4    | 0.9425683960202248 |
# |    5    | 0.9352905944926828 |
# | Average | 0.9439094857352572 |
# +---------+--------------------+
# metric EDice
# time 0:30:53.081307
# measure Micro Precision
# +---------+--------------------+
# |  split  |      DataSet1      |
# +---------+--------------------+
# |    1    | 0.9442160892542572 |
# |    2    | 0.9459776864357017 |
# |    3    | 0.9448032883147387 |
# |    4    | 0.9406928948913682 |
# |    5    | 0.9342337052260716 |
# | Average | 0.9419847328244273 |
# +---------+--------------------+
# metric EDice
# time 0:30:53.081307
# measure Macro Recall
# +---------+--------------------+
# |  split  |      DataSet1      |
# +---------+--------------------+
# |    1    | 0.9453648380802727 |
# |    2    | 0.9472966089653901 |
# |    3    | 0.9456221997362451 |
# |    4    | 0.9418373122045546 |
# |    5    | 0.935407812152769  |
# | Average | 0.9431057542278463 |
# +---------+--------------------+
# metric EDice
# time 0:30:53.081307
# measure Micro Recall
# +---------+--------------------+
# |  split  |      DataSet1      |
# +---------+--------------------+
# |    1    | 0.9442160892542572 |
# |    2    | 0.9459776864357017 |
# |    3    | 0.9448032883147387 |
# |    4    | 0.9406928948913682 |
# |    5    | 0.9342337052260716 |
# | Average | 0.9419847328244273 |
# +---------+--------------------+
# metric EDice
# time 0:30:53.081307
# measure F Measure
# +---------+--------------------+
# |  split  |      DataSet1      |
# +---------+--------------------+
# |    1    | 0.9455400156660986 |
# |    2    | 0.9477738004918147 |
# |    3    | 0.9460027560203615 |
# |    4    | 0.9421298434269577 |
# |    5    | 0.9352206655050684 |
# | Average | 0.9433334162220601 |
# +---------+--------------------+
# metric EDice
# time 0:30:53.081307
# measure Micro F Measure
# +---------+--------------------+
# |  split  |      DataSet1      |
# +---------+--------------------+
# |    1    | 0.9442160892542572 |
# |    2    | 0.9459776864357017 |
# |    3    | 0.9448032883147388 |
# |    4    | 0.9406928948913682 |
# |    5    | 0.9342337052260716 |
# | Average | 0.9419847328244277 |
# +---------+--------------------+
# metric EDice
# time 0:30:53.081307
# measure ROC
# +---------+--------------------+
# |  split  |      DataSet1      |
# +---------+--------------------+
# |    1    | 0.9670696803287443 |
# |    2    | 0.9682069094609652 |
# |    3    | 0.9672589176728558 |
# |    4    | 0.9649551677581605 |
# |    5    | 0.9611062147947295 |
# | Average | 0.965719378003091  |
# +---------+--------------------+
# ###############
# ###############
# ###############
# prob 1703
# Dist Mat shape 1703
# Element shape 3973
# (1703, 6)
# C:\Users\hassa\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1201: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
# prob 1703
# Dist Mat shape 1703
# Element shape 3973
# (1703, 6)
# C:\Users\hassa\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1201: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
# prob 1703
# Dist Mat shape 1703
# Element shape 3973
# (1703, 6)
# C:\Users\hassa\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1201: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
# prob 1703
# Dist Mat shape 1703
# Element shape 3973
# (1703, 6)
# C:\Users\hassa\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1201: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
# prob 1703
# Dist Mat shape 1703
# Element shape 3973
# (1703, 6)
# C:\Users\hassa\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1201: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
# metric ESP
# time 2:45:46.950891
# measure Accuracy
# +---------+--------------------+
# |  split  |      DataSet1      |
# +---------+--------------------+
# |    1    | 0.9448032883147387 |
# |    2    | 0.9459776864357017 |
# |    3    | 0.9453904873752202 |
# |    4    | 0.9406928948913682 |
# |    5    | 0.9342337052260716 |
# | Average | 0.9422196124486202 |
# +---------+--------------------+
# metric ESP
# time 2:45:46.950891
# measure Macro Precision
# +---------+--------------------+
# |  split  |      DataSet1      |
# +---------+--------------------+
# |    1    | 0.9471107788157095 |
# |    2    | 0.9485407584682286 |
# |    3    | 0.9472328116941656 |
# |    4    | 0.9425065773183526 |
# |    5    | 0.9354089758139862 |
# | Average | 0.9441599804220886 |
# +---------+--------------------+
# metric ESP
# time 2:45:46.950891
# measure Micro Precision
# +---------+--------------------+
# |  split  |      DataSet1      |
# +---------+--------------------+
# |    1    | 0.9448032883147387 |
# |    2    | 0.9459776864357017 |
# |    3    | 0.9453904873752202 |
# |    4    | 0.9406928948913682 |
# |    5    | 0.9342337052260716 |
# | Average | 0.9422196124486202 |
# +---------+--------------------+
# metric ESP
# time 2:45:46.950891
# measure Macro Recall
# +---------+--------------------+
# |  split  |      DataSet1      |
# +---------+--------------------+
# |    1    | 0.9459260053081066 |
# |    2    | 0.947170992734825  |
# |    3    | 0.9460577507335141 |
# |    4    | 0.9418373122045546 |
# |    5    | 0.9353943860159072 |
# | Average | 0.9432772893993814 |
# +---------+--------------------+
# metric ESP
# time 2:45:46.950891
# measure Micro Recall
# +---------+--------------------+
# |  split  |      DataSet1      |
# +---------+--------------------+
# |    1    | 0.9448032883147387 |
# |    2    | 0.9459776864357017 |
# |    3    | 0.9453904873752202 |
# |    4    | 0.9406928948913682 |
# |    5    | 0.9342337052260716 |
# | Average | 0.9422196124486202 |
# +---------+--------------------+
# metric ESP
# time 2:45:46.950891
# measure F Measure
# +---------+--------------------+
# |  split  |      DataSet1      |
# +---------+--------------------+
# |    1    | 0.9461094883901948 |
# |    2    | 0.9477318587469844 |
# |    3    | 0.9465011674058115 |
# |    4    | 0.9421068789151205 |
# |    5    | 0.9352662604722352 |
# | Average | 0.9435431307860693 |
# +---------+--------------------+
# metric ESP
# time 2:45:46.950891
# measure Micro F Measure
# +---------+--------------------+
# |  split  |      DataSet1      |
# +---------+--------------------+
# |    1    | 0.9448032883147388 |
# |    2    | 0.9459776864357017 |
# |    3    | 0.9453904873752202 |
# |    4    | 0.9406928948913682 |
# |    5    | 0.9342337052260716 |
# | Average | 0.9422196124486202 |
# +---------+--------------------+
# metric ESP
# time 2:45:46.950891
# measure ROC
# +---------+--------------------+
# |  split  |      DataSet1      |
# +---------+--------------------+
# |    1    | 0.9674094495487219 |
# |    2    | 0.9681442694869484 |
# |    3    | 0.9675357948263367 |
# |    4    | 0.9649549996767316 |
# |    5    | 0.9610971506871926 |
# | Average | 0.9658283328451862 |
# +---------+--------------------+
# ###############
# ###############
# ###############
# prob 1703
# Dist Mat shape 1703
# Element shape 3973
# (1703, 6)
# C:\Users\hassa\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1201: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
# prob 1703
# Dist Mat shape 1703
# Element shape 3973
# (1703, 6)
# C:\Users\hassa\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1201: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
# prob 1703
# Dist Mat shape 1703
# Element shape 3973
# (1703, 6)
# C:\Users\hassa\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1201: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
# prob 1703
# Dist Mat shape 1703
# Element shape 3973
# (1703, 6)
# C:\Users\hassa\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1201: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
# prob 1703
# Dist Mat shape 1703
# Element shape 3973
# (1703, 6)
# C:\Users\hassa\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1201: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
# metric EBLAB_SM
# time 0:41:12.112906
# measure Accuracy
# +---------+--------------------+
# |  split  |      DataSet1      |
# +---------+--------------------+
# |    1    | 0.9430416911332942 |
# |    2    | 0.9453904873752202 |
# |    3    | 0.9442160892542572 |
# |    4    | 0.9406928948913682 |
# |    5    | 0.9330593071051086 |
# | Average | 0.9412800939518498 |
# +---------+--------------------+
# metric EBLAB_SM
# time 0:41:12.112906
# measure Macro Precision
# +---------+--------------------+
# |  split  |      DataSet1      |
# +---------+--------------------+
# |    1    | 0.9452179523691044 |
# |    2    | 0.9479701699319025 |
# |    3    | 0.9458841402625816 |
# |    4    | 0.9425466462336258 |
# |    5    | 0.9339211359487402 |
# | Average | 0.9431080089491909 |
# +---------+--------------------+
# metric EBLAB_SM
# time 0:41:12.112906
# measure Micro Precision
# +---------+--------------------+
# |  split  |      DataSet1      |
# +---------+--------------------+
# |    1    | 0.9430416911332942 |
# |    2    | 0.9453904873752202 |
# |    3    | 0.9442160892542572 |
# |    4    | 0.9406928948913682 |
# |    5    | 0.9330593071051086 |
# | Average | 0.9412800939518498 |
# +---------+--------------------+
# metric EBLAB_SM
# time 0:41:12.112906
# measure Macro Recall
# +---------+--------------------+
# |  split  |      DataSet1      |
# +---------+--------------------+
# |    1    | 0.9442049933179301 |
# |    2    | 0.946733545902327  |
# |    3    | 0.9450755598569497 |
# |    4    | 0.9418373122045546 |
# |    5    | 0.9342740121874772 |
# | Average | 0.9424250846938478 |
# +---------+--------------------+
# metric EBLAB_SM
# time 0:41:12.112906
# measure Micro Recall
# +---------+--------------------+
# |  split  |      DataSet1      |
# +---------+--------------------+
# |    1    | 0.9430416911332942 |
# |    2    | 0.9453904873752202 |
# |    3    | 0.9442160892542572 |
# |    4    | 0.9406928948913682 |
# |    5    | 0.9330593071051086 |
# | Average | 0.9412800939518498 |
# +---------+--------------------+
# metric EBLAB_SM
# time 0:41:12.112906
# measure F Measure
# +---------+--------------------+
# |  split  |      DataSet1      |
# +---------+--------------------+
# |    1    | 0.9443159397629843 |
# |    2    | 0.9472283629549239 |
# |    3    | 0.9454021280899482 |
# |    4    | 0.9421190869639915 |
# |    5    | 0.9339515692375859 |
# | Average | 0.9426034174018867 |
# +---------+--------------------+
# metric EBLAB_SM
# time 0:41:12.112906
# measure Micro F Measure
# +---------+--------------------+
# |  split  |      DataSet1      |
# +---------+--------------------+
# |    1    | 0.9430416911332942 |
# |    2    | 0.9453904873752202 |
# |    3    | 0.9442160892542572 |
# |    4    | 0.9406928948913682 |
# |    5    | 0.9330593071051086 |
# | Average | 0.9412800939518498 |
# +---------+--------------------+
# metric EBLAB_SM
# time 0:41:12.112906
# measure ROC
# +---------+--------------------+
# |  split  |      DataSet1      |
# +---------+--------------------+
# |    1    | 0.9663733594269189 |
# |    2    | 0.967866402290909  |
# |    3    | 0.9669268698735168 |
# |    4    | 0.9649551256930531 |
# |    5    | 0.9604253936455308 |
# | Average | 0.9653094301859857 |
# +---------+--------------------+
# ###############
